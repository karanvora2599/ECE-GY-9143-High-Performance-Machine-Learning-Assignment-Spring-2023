# %%
# For tips on running notebooks in Google Colab, see
# https://pytorch.org/tutorials/beginner/colab
# %matplotlib inline

# %% [markdown]
# # Chatbot Tutorial
# **Author:** [Matthew Inkawhich](https://github.com/MatthewInkawhich)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# In this tutorial, we explore a fun and interesting use-case of recurrent
# sequence-to-sequence models. We will train a simple chatbot using movie
# scripts from the [Cornell Movie-Dialogs
# Corpus](https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html)_.
#
# Conversational models are a hot topic in artificial intelligence
# research. Chatbots can be found in a variety of settings, including
# customer service applications and online helpdesks. These bots are often
# powered by retrieval-based models, which output predefined responses to
# questions of certain forms. In a highly restricted domain like a
# company’s IT helpdesk, these models may be sufficient, however, they are
# not robust enough for more general use-cases. Teaching a machine to
# carry out a meaningful conversation with a human in multiple domains is
# a research question that is far from solved. Recently, the deep learning
# boom has allowed for powerful generative models like Google’s [Neural
# Conversational Model](https://arxiv.org/abs/1506.05869)_, which marks
# a large step towards multi-domain generative conversational models. In
# this tutorial, we will implement this kind of model in PyTorch.
#
# .. figure:: /_static/img/chatbot/bot.png
#    :align: center
#    :alt: bot
#
# .. code:: python
#
#   > hello?
#   Bot: hello .
#   > where am I?
#   Bot: you re in a hospital .
#   > who are you?
#   Bot: i m a lawyer .
#   > how are you doing?
#   Bot: i m fine .
#   > are you my friend?
#   Bot: no .
#   > you're under arrest
#   Bot: i m trying to help you !
#   > i'm just kidding
#   Bot: i m sorry .
#   > where are you from?
#   Bot: san francisco .
#   > it's time for me to leave
#   Bot: i know .
#   > goodbye
#   Bot: goodbye .
#
# **Tutorial Highlights**
#
# -  Handle loading and preprocessing of [Cornell Movie-Dialogs
#    Corpus](https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html)_
#    dataset
# -  Implement a sequence-to-sequence model with [Luong attention
#    mechanism(s)](https://arxiv.org/abs/1508.04025)_
# -  Jointly train encoder and decoder models using mini-batches
# -  Implement greedy-search decoding module
# -  Interact with trained chatbot
#
# **Acknowledgements**
#
# This tutorial borrows code from the following sources:
#
# 1) Yuan-Kuei Wu’s pytorch-chatbot implementation:
#    https://github.com/ywk991112/pytorch-chatbot
#
# 2) Sean Robertson’s practical-pytorch seq2seq-translation example:
#    https://github.com/spro/practical-pytorch/tree/master/seq2seq-translation
#
# 3) FloydHub’s Cornell Movie Corpus preprocessing code:
#    https://github.com/floydhub/textutil-preprocess-cornell-movie-corpus

# %% [markdown]
# ## Preparations
#
# To start, Download the data ZIP file
# [here](https://zissou.infosci.cornell.edu/convokit/datasets/movie-corpus/movie-corpus.zip)_

# %%
# and put in a ``data/`` directory under the current directory.
#
# After that, let’s import some necessities.
#

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

import torch
from torch.jit import script, trace
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import csv
import random
import re
import os
import unicodedata
import codecs
from io import open
import itertools
import math
import json


USE_CUDA = torch.cuda.is_available()
device = torch.device("cuda" if USE_CUDA else "cpu")

# %% [markdown]
# ## Load & Preprocess Data
#
# The next step is to reformat our data file and load the data into
# structures that we can work with.
#
# The [Cornell Movie-Dialogs
# Corpus](https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html)_
# is a rich dataset of movie character dialog:
#
# -  220,579 conversational exchanges between 10,292 pairs of movie
#    characters
# -  9,035 characters from 617 movies
# -  304,713 total utterances
#
# This dataset is large and diverse, and there is a great variation of
# language formality, time periods, sentiment, etc. Our hope is that this
# diversity makes our model robust to many forms of inputs and queries.
#
# First, we’ll take a look at some lines of our datafile to see the
# original format.

# %%
corpus_name = "movie-corpus"
corpus = os.path.join("/content/drive/MyDrive/data", corpus_name)

def printLines(file, n=10):
    with open(file, 'rb') as datafile:
        lines = datafile.readlines()
    for line in lines[:n]:
        print(line)

printLines(os.path.join(corpus, "utterances.jsonl"))
# Out:
# b'{"id": "L1045", "conversation_id": "L1044", "text": "They do not!", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "They", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "not", "tag": "RB", "dep": "neg", "up": 1, "dn": []}, {"tok": "!", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": "L1044", "timestamp": null, "vectors": []}\n'
# b'{"id": "L1044", "conversation_id": "L1044", "text": "They do to!", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "They", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "to", "tag": "TO", "dep": "dobj", "up": 1, "dn": []}, {"tok": "!", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L985", "conversation_id": "L984", "text": "I hope so.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "I", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "hope", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "so", "tag": "RB", "dep": "advmod", "up": 1, "dn": []}, {"tok": ".", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": "L984", "timestamp": null, "vectors": []}\n'
# b'{"id": "L984", "conversation_id": "L984", "text": "She okay?", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "She", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "okay", "tag": "RB", "dep": "ROOT", "dn": [0, 2]}, {"tok": "?", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L925", "conversation_id": "L924", "text": "Let\'s go.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Let", "tag": "VB", "dep": "ROOT", "dn": [2, 3]}, {"tok": "\'s", "tag": "PRP", "dep": "nsubj", "up": 2, "dn": []}, {"tok": "go", "tag": "VB", "dep": "ccomp", "up": 0, "dn": [1]}, {"tok": ".", "tag": ".", "dep": "punct", "up": 0, "dn": []}]}]}, "reply-to": "L924", "timestamp": null, "vectors": []}\n'
# b'{"id": "L924", "conversation_id": "L924", "text": "Wow", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Wow", "tag": "UH", "dep": "ROOT", "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L872", "conversation_id": "L870", "text": "Okay -- you\'re gonna need to learn how to lie.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 4, "toks": [{"tok": "Okay", "tag": "UH", "dep": "intj", "up": 4, "dn": []}, {"tok": "--", "tag": ":", "dep": "punct", "up": 4, "dn": []}, {"tok": "you", "tag": "PRP", "dep": "nsubj", "up": 4, "dn": []}, {"tok": "\'re", "tag": "VBP", "dep": "aux", "up": 4, "dn": []}, {"tok": "gon", "tag": "VBG", "dep": "ROOT", "dn": [0, 1, 2, 3, 6, 12]}, {"tok": "na", "tag": "TO", "dep": "aux", "up": 6, "dn": []}, {"tok": "need", "tag": "VB", "dep": "xcomp", "up": 4, "dn": [5, 8]}, {"tok": "to", "tag": "TO", "dep": "aux", "up": 8, "dn": []}, {"tok": "learn", "tag": "VB", "dep": "xcomp", "up": 6, "dn": [7, 11]}, {"tok": "how", "tag": "WRB", "dep": "advmod", "up": 11, "dn": []}, {"tok": "to", "tag": "TO", "dep": "aux", "up": 11, "dn": []}, {"tok": "lie", "tag": "VB", "dep": "xcomp", "up": 8, "dn": [9, 10]}, {"tok": ".", "tag": ".", "dep": "punct", "up": 4, "dn": []}]}]}, "reply-to": "L871", "timestamp": null, "vectors": []}\n'
# b'{"id": "L871", "conversation_id": "L870", "text": "No", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "No", "tag": "UH", "dep": "ROOT", "dn": []}]}]}, "reply-to": "L870", "timestamp": null, "vectors": []}\n'
# b'{"id": "L870", "conversation_id": "L870", "text": "I\'m kidding.  You know how sometimes you just become this \\"persona\\"?  And you don\'t know how to quit?", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 2, "toks": [{"tok": "I", "tag": "PRP", "dep": "nsubj", "up": 2, "dn": []}, {"tok": "\'m", "tag": "VBP", "dep": "aux", "up": 2, "dn": []}, {"tok": "kidding", "tag": "VBG", "dep": "ROOT", "dn": [0, 1, 3]}, {"tok": ".", "tag": ".", "dep": "punct", "up": 2, "dn": [4]}, {"tok": " ", "tag": "_SP", "dep": "", "up": 3, "dn": []}]}, {"rt": 1, "toks": [{"tok": "You", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "know", "tag": "VBP", "dep": "ROOT", "dn": [0, 6, 11]}, {"tok": "how", "tag": "WRB", "dep": "advmod", "up": 3, "dn": []}, {"tok": "sometimes", "tag": "RB", "dep": "advmod", "up": 6, "dn": [2]}, {"tok": "you", "tag": "PRP", "dep": "nsubj", "up": 6, "dn": []}, {"tok": "just", "tag": "RB", "dep": "advmod", "up": 6, "dn": []}, {"tok": "become", "tag": "VBP", "dep": "ccomp", "up": 1, "dn": [3, 4, 5, 9]}, {"tok": "this", "tag": "DT", "dep": "det", "up": 9, "dn": []}, {"tok": "\\"", "tag": "``", "dep": "punct", "up": 9, "dn": []}, {"tok": "persona", "tag": "NN", "dep": "attr", "up": 6, "dn": [7, 8, 10]}, {"tok": "\\"", "tag": "\'\'", "dep": "punct", "up": 9, "dn": []}, {"tok": "?", "tag": ".", "dep": "punct", "up": 1, "dn": [12]}, {"tok": " ", "tag": "_SP", "dep": "", "up": 11, "dn": []}]}, {"rt": 4, "toks": [{"tok": "And", "tag": "CC", "dep": "cc", "up": 4, "dn": []}, {"tok": "you", "tag": "PRP", "dep": "nsubj", "up": 4, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "aux", "up": 4, "dn": []}, {"tok": "n\'t", "tag": "RB", "dep": "neg", "up": 4, "dn": []}, {"tok": "know", "tag": "VB", "dep": "ROOT", "dn": [0, 1, 2, 3, 7, 8]}, {"tok": "how", "tag": "WRB", "dep": "advmod", "up": 7, "dn": []}, {"tok": "to", "tag": "TO", "dep": "aux", "up": 7, "dn": []}, {"tok": "quit", "tag": "VB", "dep": "xcomp", "up": 4, "dn": [5, 6]}, {"tok": "?", "tag": ".", "dep": "punct", "up": 4, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L869", "conversation_id": "L866", "text": "Like my fear of wearing pastels?", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Like", "tag": "IN", "dep": "ROOT", "dn": [2, 6]}, {"tok": "my", "tag": "PRP$", "dep": "poss", "up": 2, "dn": []}, {"tok": "fear", "tag": "NN", "dep": "pobj", "up": 0, "dn": [1, 3]}, {"tok": "of", "tag": "IN", "dep": "prep", "up": 2, "dn": [4]}, {"tok": "wearing", "tag": "VBG", "dep": "pcomp", "up": 3, "dn": [5]}, {"tok": "pastels", "tag": "NNS", "dep": "dobj", "up": 4, "dn": []}, {"tok": "?", "tag": ".", "dep": "punct", "up": 0, "dn": []}]}]}, "reply-to": "L868", "timestamp": null, "vectors": []}\n'

# %% [markdown]
# ### Create formatted data file
#
# For convenience, we'll create a nicely formatted data file in which each line
# contains a tab-separated *query sentence* and a *response sentence* pair.
#
# The following functions facilitate the parsing of the raw
# *utterances.jsonl* data file.
#
# -  ``loadLinesAndConversations`` splits each line of the file into a dictionary of
#    lines with fields: lineID, characterID, and text and then groups them
#    into conversations with fields: conversationID, movieID, and lines.
# -  ``extractSentencePairs`` extracts pairs of sentences from
#    conversations

# %%
# Splits each line of the file to create lines and conversations
def loadLinesAndConversations(fileName):
    lines = {}
    conversations = {}
    with open(fileName, 'r', encoding='iso-8859-1') as f:
        for line in f:
            lineJson = json.loads(line)
            # Extract fields for line object
            lineObj = {}
            lineObj["lineID"] = lineJson["id"]
            lineObj["characterID"] = lineJson["speaker"]
            lineObj["text"] = lineJson["text"]
            lines[lineObj['lineID']] = lineObj

            # Extract fields for conversation object
            if lineJson["conversation_id"] not in conversations:
                convObj = {}
                convObj["conversationID"] = lineJson["conversation_id"]
                convObj["movieID"] = lineJson["meta"]["movie_id"]
                convObj["lines"] = [lineObj]
            else:
                convObj = conversations[lineJson["conversation_id"]]
                convObj["lines"].insert(0, lineObj)
            conversations[convObj["conversationID"]] = convObj

    return lines, conversations


# Extracts pairs of sentences from conversations
def extractSentencePairs(conversations):
    qa_pairs = []
    for conversation in conversations.values():
        # Iterate over all the lines of the conversation
        for i in range(len(conversation["lines"]) - 1):  # We ignore the last line (no answer for it)
            inputLine = conversation["lines"][i]["text"].strip()
            targetLine = conversation["lines"][i+1]["text"].strip()
            # Filter wrong samples (if one of the lists is empty)
            if inputLine and targetLine:
                qa_pairs.append([inputLine, targetLine])
    return qa_pairs

# %% [markdown]
# Now we’ll call these functions and create the file. We’ll call it
# *formatted_movie_lines.txt*.

# %%
# Define path to new file
datafile = os.path.join(corpus, "formatted_movie_lines.txt")

delimiter = '\t'
# Unescape the delimiter
delimiter = str(codecs.decode(delimiter, "unicode_escape"))

# Initialize lines dict and conversations dict
lines = {}
conversations = {}
# Load lines and conversations
print("\nProcessing corpus into lines and conversations...")
lines, conversations = loadLinesAndConversations(os.path.join(corpus, "utterances.jsonl"))

# Write new csv file
print("\nWriting newly formatted file...")
with open(datafile, 'w', encoding='utf-8') as outputfile:
    writer = csv.writer(outputfile, delimiter=delimiter, lineterminator='\n')
    for pair in extractSentencePairs(conversations):
        writer.writerow(pair)

# Print a sample of lines
print("\nSample lines from file:")
printLines(datafile)
# Out:
# Processing corpus into lines and conversations...
#
# Writing newly formatted file...
#
# Sample lines from file:
# b'They do to!\tThey do not!\n'
# b'She okay?\tI hope so.\n'
# b"Wow\tLet's go.\n"
# b'"I\'m kidding.  You know how sometimes you just become this ""persona""?  And you don\'t know how to quit?"\tNo\n'
# b"No\tOkay -- you're gonna need to learn how to lie.\n"
# b"I figured you'd get to the good stuff eventually.\tWhat good stuff?\n"
# b'What good stuff?\t"The ""real you""."\n'
# b'"The ""real you""."\tLike my fear of wearing pastels?\n'
# b'do you listen to this crap?\tWhat crap?\n'
# b"What crap?\tMe.  This endless ...blonde babble. I'm like, boring myself.\n"

# %% [markdown]
# ### Load and trim data
#
# Our next order of business is to create a vocabulary and load
# query/response sentence pairs into memory.
#
# Note that we are dealing with sequences of **words**, which do not have
# an implicit mapping to a discrete numerical space. Thus, we must create
# one by mapping each unique word that we encounter in our dataset to an
# index value.
#
# For this we define a ``Voc`` class, which keeps a mapping from words to
# indexes, a reverse mapping of indexes to words, a count of each word and
# a total word count. The class provides methods for adding a word to the
# vocabulary (``addWord``), adding all words in a sentence
# (``addSentence``) and trimming infrequently seen words (``trim``). More
# on trimming later.

# %%
# Default word tokens
PAD_token = 0  # Used for padding short sentences
SOS_token = 1  # Start-of-sentence token
EOS_token = 2  # End-of-sentence token

class Voc:
    def __init__(self, name):
        self.name = name
        self.trimmed = False
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3  # Count SOS, EOS, PAD

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.num_words
            self.word2count[word] = 1
            self.index2word[self.num_words] = word
            self.num_words += 1
        else:
            self.word2count[word] += 1

    # Remove words below a certain count threshold
    def trim(self, min_count):
        if self.trimmed:
            return
        self.trimmed = True

        keep_words = []

        for k, v in self.word2count.items():
            if v >= min_count:
                keep_words.append(k)

        print('keep_words {} / {} = {:.4f}'.format(
            len(keep_words), len(self.word2index), len(keep_words) / len(self.word2index)
        ))

        # Reinitialize dictionaries
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3 # Count default tokens

        for word in keep_words:
            self.addWord(word)

# %% [markdown]
# Now we can assemble our vocabulary and query/response sentence pairs.
# Before we are ready to use this data, we must perform some
# preprocessing.
#
# First, we must convert the Unicode strings to ASCII using
# ``unicodeToAscii``. Next, we should convert all letters to lowercase and
# trim all non-letter characters except for basic punctuation
# (``normalizeString``). Finally, to aid in training convergence, we will
# filter out sentences with length greater than the ``MAX_LENGTH``
# threshold (``filterPairs``).

# %%
MAX_LENGTH = 10  # Maximum sentence length to consider

# Turn a Unicode string to plain ASCII, thanks to
# https://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# Lowercase, trim, and remove non-letter characters
def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    s = re.sub(r"\s+", r" ", s).strip()
    return s

# Read query/response pairs and return a voc object
def readVocs(datafile, corpus_name):
    print("Reading lines...")
    # Read the file and split into lines
    lines = open(datafile, encoding='utf-8').\
        read().strip().split('\n')
    # Split every line into pairs and normalize
    pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]
    voc = Voc(corpus_name)
    return voc, pairs

# Returns True iff both sentences in a pair 'p' are under the MAX_LENGTH threshold
def filterPair(p):
    # Input sequences need to preserve the last word for EOS token
    return len(p[0].split(' ')) < MAX_LENGTH and len(p[1].split(' ')) < MAX_LENGTH

# Filter pairs using filterPair condition
def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# Using the functions defined above, return a populated voc object and pairs list
def loadPrepareData(corpus, corpus_name, datafile, save_dir):
    print("Start preparing training data ...")
    voc, pairs = readVocs(datafile, corpus_name)
    print("Read {!s} sentence pairs".format(len(pairs)))
    pairs = filterPairs(pairs)
    print("Trimmed to {!s} sentence pairs".format(len(pairs)))
    print("Counting words...")
    for pair in pairs:
        voc.addSentence(pair[0])
        voc.addSentence(pair[1])
    print("Counted words:", voc.num_words)
    return voc, pairs


# Load/Assemble voc and pairs
save_dir = os.path.join("data", "save")
voc, pairs = loadPrepareData(corpus, corpus_name, datafile, save_dir)
# Print some pairs to validate
print("\npairs:")
for pair in pairs[:10]:
    print(pair)
# Out:
# Start preparing training data ...
# Reading lines...
# Read 221282 sentence pairs
# Trimmed to 64313 sentence pairs
# Counting words...
# Counted words: 18082
#
# pairs:
# ['they do to !', 'they do not !']
# ['she okay ?', 'i hope so .']
# ['wow', 'let s go .']
# ['what good stuff ?', 'the real you .']
# ['the real you .', 'like my fear of wearing pastels ?']
# ['do you listen to this crap ?', 'what crap ?']
# ['well no . . .', 'then that s all you had to say .']
# ['then that s all you had to say .', 'but']
# ['but', 'you always been this selfish ?']
# ['have fun tonight ?', 'tons']

# %% [markdown]
# Another tactic that is beneficial to achieving faster convergence during
# training is trimming rarely used words out of our vocabulary. Decreasing
# the feature space will also soften the difficulty of the function that
# the model must learn to approximate. We will do this as a two-step
# process:
#
# 1) Trim words used under ``MIN_COUNT`` threshold using the ``voc.trim``
#    function.
#
# 2) Filter out pairs with trimmed words.

# %%
MIN_COUNT = 3    # Minimum word count threshold for trimming

def trimRareWords(voc, pairs, MIN_COUNT):
    # Trim words used under the MIN_COUNT from the voc
    voc.trim(MIN_COUNT)
    # Filter out pairs with trimmed words
    keep_pairs = []
    for pair in pairs:
        input_sentence = pair[0]
        output_sentence = pair[1]
        keep_input = True
        keep_output = True
        # Check input sentence
        for word in input_sentence.split(' '):
            if word not in voc.word2index:
                keep_input = False
                break
        # Check output sentence
        for word in output_sentence.split(' '):
            if word not in voc.word2index:
                keep_output = False
                break

        # Only keep pairs that do not contain trimmed word(s) in their input or output sentence
        if keep_input and keep_output:
            keep_pairs.append(pair)

    print("Trimmed from {} pairs to {}, {:.4f} of total".format(len(pairs), len(keep_pairs), len(keep_pairs) / len(pairs)))
    return keep_pairs


# Trim voc and pairs
pairs = trimRareWords(voc, pairs, MIN_COUNT)
# Out:
# keep_words 7833 / 18079 = 0.4333
# Trimmed from 64313 pairs to 53131, 0.8261 of total

# %% [markdown]
# ## Prepare Data for Models
#
# Although we have put a great deal of effort into preparing and massaging our
# data into a nice vocabulary object and list of sentence pairs, our models
# will ultimately expect numerical torch tensors as inputs. One way to
# prepare the processed data for the models can be found in the [seq2seq
# translation
# tutorial](https://pytorch.org/tutorials/intermediate/seq2seq_translation_tutorial.html)_.
# In that tutorial, we use a batch size of 1, meaning that all we have to
# do is convert the words in our sentence pairs to their corresponding
# indexes from the vocabulary and feed this to the models.
#
# However, if you’re interested in speeding up training and/or would like
# to leverage GPU parallelization capabilities, you will need to train
# with mini-batches.
#
# Using mini-batches also means that we must be mindful of the variation
# of sentence length in our batches. To accommodate sentences of different
# sizes in the same batch, we will make our batched input tensor of shape
# *(max_length, batch_size)*, where sentences shorter than the
# *max_length* are zero padded after an *EOS_token*.
#
# If we simply convert our English sentences to tensors by converting
# words to their indexes(\ ``indexesFromSentence``) and zero-pad, our
# tensor would have shape *(batch_size, max_length)* and indexing the
# first dimension would return a full sequence across all time-steps.
# However, we need to be able to index our batch along time, and across
# all sequences in the batch. Therefore, we transpose our input batch
# shape to *(max_length, batch_size)*, so that indexing across the first
# dimension returns a time step across all sentences in the batch. We
# handle this transpose implicitly in the ``zeroPadding`` function.
#
# .. figure:: /_static/img/chatbot/seq2seq_batches.png
#    :align: center
#    :alt: batches
#
# The ``inputVar`` function handles the process of converting sentences to
# tensor, ultimately creating a correctly shaped zero-padded tensor. It
# also returns a tensor of ``lengths`` for each of the sequences in the
# batch which will be passed to our decoder later.
#
# The ``outputVar`` function performs a similar function to ``inputVar``,
# but instead of returning a ``lengths`` tensor, it returns a binary mask
# tensor and a maximum target sentence length. The binary mask tensor has
# the same shape as the output target tensor, but every element that is a
# *PAD_token* is 0 and all others are 1.
#
# ``batch2TrainData`` simply takes a bunch of pairs and returns the input
# and target tensors using the aforementioned functions.

# %%
def indexesFromSentence(voc, sentence):
    return [voc.word2index[word] for word in sentence.split(' ')] + [EOS_token]


def zeroPadding(l, fillvalue=PAD_token):
    return list(itertools.zip_longest(*l, fillvalue=fillvalue))

def binaryMatrix(l, value=PAD_token):
    m = []
    for i, seq in enumerate(l):
        m.append([])
        for token in seq:
            if token == PAD_token:
                m[i].append(0)
            else:
                m[i].append(1)
    return m

# Returns padded input sequence tensor and lengths
def inputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    padVar = torch.LongTensor(padList)
    return padVar, lengths

# Returns padded target sequence tensor, padding mask, and max target length
def outputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    max_target_len = max([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    mask = binaryMatrix(padList)
    mask = torch.BoolTensor(mask)
    padVar = torch.LongTensor(padList)
    return padVar, mask, max_target_len

# Returns all items for a given batch of pairs
def batch2TrainData(voc, pair_batch):
    pair_batch.sort(key=lambda x: len(x[0].split(" ")), reverse=True)
    input_batch, output_batch = [], []
    for pair in pair_batch:
        input_batch.append(pair[0])
        output_batch.append(pair[1])
    inp, lengths = inputVar(input_batch, voc)
    output, mask, max_target_len = outputVar(output_batch, voc)
    return inp, lengths, output, mask, max_target_len


# Example for validation
small_batch_size = 5
batches = batch2TrainData(voc, [random.choice(pairs) for _ in range(small_batch_size)])
input_variable, lengths, target_variable, mask, max_target_len = batches

print("input_variable:", input_variable)
print("lengths:", lengths)
print("target_variable:", target_variable)
print("mask:", mask)
print("max_target_len:", max_target_len)
# Out:
# input_variable: tensor([[  19,   14,   24,  789,   54],
#         [  69,   14,  449,   59, 4968],
#         [  24, 2146,  609,   10,   14],
#         [  83,   28, 3109,    2,    2],
#         [  28,  819,   14,    0,    0],
#         [  72,   14,    2,    0,    0],
#         [ 317,    2,    0,    0,    0],
#         [   2,    0,    0,    0,    0]])
# lengths: tensor([8, 7, 6, 4, 4])
# target_variable: tensor([[ 296,   35,   36,   96,  780],
#         [  11,   18,   17,   14, 4801],
#         [ 246,  484,   37,    2,   14],
#         [ 135,  132,   11,    0,    2],
#         [  83,  222,  355,    0,    0],
#         [  28,   84,   94,    0,    0],
#         [  24,   85,    6,    0,    0],
#         [ 126,   14,    2,    0,    0],
#         [  14,    2,    0,    0,    0],
#         [   2,    0,    0,    0,    0]])
# mask: tensor([[ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True, False,  True],
#         [ True,  True,  True, False, False],
#         [ True,  True,  True, False, False],
#         [ True,  True,  True, False, False],
#         [ True,  True,  True, False, False],
#         [ True,  True, False, False, False],
#         [ True, False, False, False, False]])
# max_target_len: 10

# %% [markdown]
# ## Define Models
#
# ### Seq2Seq Model
#
# The brains of our chatbot is a sequence-to-sequence (seq2seq) model. The
# goal of a seq2seq model is to take a variable-length sequence as an
# input, and return a variable-length sequence as an output using a
# fixed-sized model.
#
# [Sutskever et al.](https://arxiv.org/abs/1409.3215)_ discovered that
# by using two separate recurrent neural nets together, we can accomplish
# this task. One RNN acts as an **encoder**, which encodes a variable
# length input sequence to a fixed-length context vector. In theory, this
# context vector (the final hidden layer of the RNN) will contain semantic
# information about the query sentence that is input to the bot. The
# second RNN is a **decoder**, which takes an input word and the context
# vector, and returns a guess for the next word in the sequence and a
# hidden state to use in the next iteration.
#
# .. figure:: /_static/img/chatbot/seq2seq_ts.png
#    :align: center
#    :alt: model
#
# Image source:
# https://jeddy92.github.io/JEddy92.github.io/ts_seq2seq_intro/

# %% [markdown]
# ### Encoder
#
# The encoder RNN iterates through the input sentence one token
# (e.g. word) at a time, at each time step outputting an “output” vector
# and a “hidden state” vector. The hidden state vector is then passed to
# the next time step, while the output vector is recorded. The encoder
# transforms the context it saw at each point in the sequence into a set
# of points in a high-dimensional space, which the decoder will use to
# generate a meaningful output for the given task.
#
# At the heart of our encoder is a multi-layered Gated Recurrent Unit,
# invented by [Cho et al.](https://arxiv.org/pdf/1406.1078v3.pdf)_ in
# 2014. We will use a bidirectional variant of the GRU, meaning that there
# are essentially two independent RNNs: one that is fed the input sequence
# in normal sequential order, and one that is fed the input sequence in
# reverse order. The outputs of each network are summed at each time step.
# Using a bidirectional GRU will give us the advantage of encoding both
# past and future contexts.
#
# Bidirectional RNN:
#
# .. figure:: /_static/img/chatbot/RNN-bidirectional.png
#    :width: 70%
#    :align: center
#    :alt: rnn_bidir
#
# Image source: https://colah.github.io/posts/2015-09-NN-Types-FP/
#
# Note that an ``embedding`` layer is used to encode our word indices in
# an arbitrarily sized feature space. For our models, this layer will map
# each word to a feature space of size *hidden_size*. When trained, these
# values should encode semantic similarity between similar meaning words.
#
# Finally, if passing a padded batch of sequences to an RNN module, we
# must pack and unpack padding around the RNN pass using
# ``nn.utils.rnn.pack_padded_sequence`` and
# ``nn.utils.rnn.pad_packed_sequence`` respectively.
#
# **Computation Graph:**
#
#    1) Convert word indexes to embeddings.
#    2) Pack padded batch of sequences for RNN module.
#    3) Forward pass through GRU.
#    4) Unpack padding.
#    5) Sum bidirectional GRU outputs.
#    6) Return output and final hidden state.
#
# **Inputs:**
#
# -  ``input_seq``: batch of input sentences; shape=\ *(max_length,
#    batch_size)*
# -  ``input_lengths``: list of sentence lengths corresponding to each
#    sentence in the batch; shape=\ *(batch_size)*
# -  ``hidden``: hidden state; shape=\ *(n_layers x num_directions,
#    batch_size, hidden_size)*
#
# **Outputs:**
#
# -  ``outputs``: output features from the last hidden layer of the GRU
#    (sum of bidirectional outputs); shape=\ *(max_length, batch_size,
#    hidden_size)*
# -  ``hidden``: updated hidden state from GRU; shape=\ *(n_layers x
#    num_directions, batch_size, hidden_size)*

# %%
class EncoderRNN(nn.Module):
    def __init__(self, hidden_size, embedding, n_layers=1, dropout=0):
        super(EncoderRNN, self).__init__()
        self.n_layers = n_layers
        self.hidden_size = hidden_size
        self.embedding = embedding

        # Initialize GRU; the input_size and hidden_size params are both set to 'hidden_size'
        #   because our input size is a word embedding with number of features == hidden_size
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers,
                          dropout=(0 if n_layers == 1 else dropout), bidirectional=True)

    #@torch.jit.script_method
    def forward(self, input_seq, input_lengths, hidden=None):
        # Convert word indexes to embeddings
        embedded = self.embedding(input_seq)
        # Pack padded batch of sequences for RNN module
        packed = nn.utils.rnn.pack_padded_sequence(embedded, input_lengths)
        # Forward pass through GRU
        outputs, hidden = self.gru(packed, hidden)
        # Unpack padding
        outputs, _ = nn.utils.rnn.pad_packed_sequence(outputs)
        # Sum bidirectional GRU outputs
        outputs = outputs[:, :, :self.hidden_size] + outputs[:, : ,self.hidden_size:]
        # Return output and final hidden state
        return outputs, hidden

# %% [markdown]
# ### Decoder
#
# The decoder RNN generates the response sentence in a token-by-token
# fashion. It uses the encoder’s context vectors, and internal hidden
# states to generate the next word in the sequence. It continues
# generating words until it outputs an *EOS_token*, representing the end
# of the sentence. A common problem with a vanilla seq2seq decoder is that
# if we rely solely on the context vector to encode the entire input
# sequence’s meaning, it is likely that we will have information loss.
# This is especially the case when dealing with long input sequences,
# greatly limiting the capability of our decoder.
#
# To combat this, [Bahdanau et al.](https://arxiv.org/abs/1409.0473)_
# created an “attention mechanism” that allows the decoder to pay
# attention to certain parts of the input sequence, rather than using the
# entire fixed context at every step.
#
# At a high level, attention is calculated using the decoder’s current
# hidden state and the encoder’s outputs. The output attention weights
# have the same shape as the input sequence, allowing us to multiply them
# by the encoder outputs, giving us a weighted sum which indicates the
# parts of encoder output to pay attention to. [Sean
# Robertson’s](https://github.com/spro)_ figure describes this very
# well:
#
# .. figure:: /_static/img/chatbot/attn2.png
#    :align: center
#    :alt: attn2
#
# [Luong et al.](https://arxiv.org/abs/1508.04025)_ improved upon
# Bahdanau et al.’s groundwork by creating “Global attention”. The key
# difference is that with “Global attention”, we consider all of the
# encoder’s hidden states, as opposed to Bahdanau et al.’s “Local
# attention”, which only considers the encoder’s hidden state from the
# current time step. Another difference is that with “Global attention”,
# we calculate attention weights, or energies, using the hidden state of
# the decoder from the current time step only. Bahdanau et al.’s attention
# calculation requires knowledge of the decoder’s state from the previous
# time step. Also, Luong et al. provides various methods to calculate the
# attention energies between the encoder output and decoder output which
# are called “score functions”:
#
# .. figure:: /_static/img/chatbot/scores.png
#    :width: 60%
#    :align: center
#    :alt: scores
#
# where $h_t$ = current target decoder state and $\bar{h}_s$ =
# all encoder states.
#
# Overall, the Global attention mechanism can be summarized by the
# following figure. Note that we will implement the “Attention Layer” as a
# separate ``nn.Module`` called ``Attn``. The output of this module is a
# softmax normalized weights tensor of shape *(batch_size, 1,
# max_length)*.
#
# .. figure:: /_static/img/chatbot/global_attn.png
#    :align: center
#    :width: 60%
#    :alt: global_attn

# %%
# Luong attention layer
class Attn(nn.Module):
    def __init__(self, method, hidden_size):
        super(Attn, self).__init__()
        self.method = method
        if self.method not in ['dot', 'general', 'concat']:
            raise ValueError(self.method, "is not an appropriate attention method.")
        self.hidden_size = hidden_size
        if self.method == 'general':
            self.attn = nn.Linear(self.hidden_size, hidden_size)
        elif self.method == 'concat':
            self.attn = nn.Linear(self.hidden_size * 2, hidden_size)
            self.v = nn.Parameter(torch.FloatTensor(hidden_size))

    def dot_score(self, hidden, encoder_output):
        return torch.sum(hidden * encoder_output, dim=2)

    def general_score(self, hidden, encoder_output):
        energy = self.attn(encoder_output)
        return torch.sum(hidden * energy, dim=2)

    def concat_score(self, hidden, encoder_output):
        energy = self.attn(torch.cat((hidden.expand(encoder_output.size(0), -1, -1), encoder_output), 2)).tanh()
        return torch.sum(self.v * energy, dim=2)

    def forward(self, hidden, encoder_outputs):
        # Calculate the attention weights (energies) based on the given method
        if self.method == 'general':
            attn_energies = self.general_score(hidden, encoder_outputs)
        elif self.method == 'concat':
            attn_energies = self.concat_score(hidden, encoder_outputs)
        elif self.method == 'dot':
            attn_energies = self.dot_score(hidden, encoder_outputs)

        # Transpose max_length and batch_size dimensions
        attn_energies = attn_energies.t()

        # Return the softmax normalized probability scores (with added dimension)
        return F.softmax(attn_energies, dim=1).unsqueeze(1)

# %% [markdown]
# Now that we have defined our attention submodule, we can implement the
# actual decoder model. For the decoder, we will manually feed our batch
# one time step at a time. This means that our embedded word tensor and
# GRU output will both have shape *(1, batch_size, hidden_size)*.
#
# **Computation Graph:**
#
#    1) Get embedding of current input word.
#    2) Forward through unidirectional GRU.
#    3) Calculate attention weights from the current GRU output from (2).
#    4) Multiply attention weights to encoder outputs to get new "weighted sum" context vector.
#    5) Concatenate weighted context vector and GRU output using Luong eq. 5.
#    6) Predict next word using Luong eq. 6 (without softmax).
#    7) Return output and final hidden state.
#
# **Inputs:**
#
# -  ``input_step``: one time step (one word) of input sequence batch;
#    shape=\ *(1, batch_size)*
# -  ``last_hidden``: final hidden layer of GRU; shape=\ *(n_layers x
#    num_directions, batch_size, hidden_size)*
# -  ``encoder_outputs``: encoder model’s output; shape=\ *(max_length,
#    batch_size, hidden_size)*
#
# **Outputs:**
#
# -  ``output``: softmax normalized tensor giving probabilities of each
#    word being the correct next word in the decoded sequence;
#    shape=\ *(batch_size, voc.num_words)*
# -  ``hidden``: final hidden state of GRU; shape=\ *(n_layers x
#    num_directions, batch_size, hidden_size)*

# %%
class LuongAttnDecoderRNN(nn.Module):
    def __init__(self, attn_model, embedding, hidden_size, output_size, n_layers=1, dropout=0.1):
        super(LuongAttnDecoderRNN, self).__init__()

        # Keep for reference
        self.attn_model = attn_model
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.dropout = dropout

        # Define layers
        self.embedding = embedding
        self.embedding_dropout = nn.Dropout(dropout)
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers, dropout=(0 if n_layers == 1 else dropout))
        self.concat = nn.Linear(hidden_size * 2, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)

        self.attn = Attn(attn_model, hidden_size)
        
    #@torch.jit.script_method
    def forward(self, input_step, last_hidden, encoder_outputs):
        # Note: we run this one step (word) at a time
        # Get embedding of current input word
        embedded = self.embedding(input_step)
        embedded = self.embedding_dropout(embedded)
        # Forward through unidirectional GRU
        rnn_output, hidden = self.gru(embedded, last_hidden)
        # Calculate attention weights from the current GRU output
        attn_weights = self.attn(rnn_output, encoder_outputs)
        # Multiply attention weights to encoder outputs to get new "weighted sum" context vector
        context = attn_weights.bmm(encoder_outputs.transpose(0, 1))
        # Concatenate weighted context vector and GRU output using Luong eq. 5
        rnn_output = rnn_output.squeeze(0)
        context = context.squeeze(1)
        concat_input = torch.cat((rnn_output, context), 1)
        concat_output = torch.tanh(self.concat(concat_input))
        # Predict next word using Luong eq. 6
        output = self.out(concat_output)
        output = F.softmax(output, dim=1)
        # Return output and final hidden state
        return output, hidden

# %% [markdown]
# ## Define Training Procedure
#
# ### Masked loss
#
# Since we are dealing with batches of padded sequences, we cannot simply
# consider all elements of the tensor when calculating loss. We define
# ``maskNLLLoss`` to calculate our loss based on our decoder’s output
# tensor, the target tensor, and a binary mask tensor describing the
# padding of the target tensor. This loss function calculates the average
# negative log likelihood of the elements that correspond to a *1* in the
# mask tensor.

# %%
def maskNLLLoss(inp, target, mask):
    nTotal = mask.sum()
    crossEntropy = -torch.log(torch.gather(inp, 1, target.view(-1, 1)).squeeze(1))
    loss = crossEntropy.masked_select(mask).mean()
    loss = loss.to(device)
    return loss, nTotal.item()

# %% [markdown]
# ### Single training iteration
#
# The ``train`` function contains the algorithm for a single training
# iteration (a single batch of inputs).
#
# We will use a couple of clever tricks to aid in convergence:
#
# -  The first trick is using **teacher forcing**. This means that at some
#    probability, set by ``teacher_forcing_ratio``, we use the current
#    target word as the decoder’s next input rather than using the
#    decoder’s current guess. This technique acts as training wheels for
#    the decoder, aiding in more efficient training. However, teacher
#    forcing can lead to model instability during inference, as the
#    decoder may not have a sufficient chance to truly craft its own
#    output sequences during training. Thus, we must be mindful of how we
#    are setting the ``teacher_forcing_ratio``, and not be fooled by fast
#    convergence.
#
# -  The second trick that we implement is **gradient clipping**. This is
#    a commonly used technique for countering the “exploding gradient”
#    problem. In essence, by clipping or thresholding gradients to a
#    maximum value, we prevent the gradients from growing exponentially
#    and either overflow (NaN), or overshoot steep cliffs in the cost
#    function.
#
# .. figure:: /_static/img/chatbot/grad_clip.png
#    :align: center
#    :width: 60%
#    :alt: grad_clip
#
# Image source: Goodfellow et al. *Deep Learning*. 2016. https://www.deeplearningbook.org/
#
# **Sequence of Operations:**
#
#    1) Forward pass entire input batch through encoder.
#    2) Initialize decoder inputs as SOS_token, and hidden state as the encoder's final hidden state.
#    3) Forward input batch sequence through decoder one time step at a time.
#    4) If teacher forcing: set next decoder input as the current target; else: set next decoder input as current decoder output.
#    5) Calculate and accumulate loss.
#    6) Perform backpropagation.
#    7) Clip gradients.
#    8) Update encoder and decoder model parameters.
#
#
# .. Note ::
#
#   PyTorch’s RNN modules (``RNN``, ``LSTM``, ``GRU``) can be used like any
#   other non-recurrent layers by simply passing them the entire input
#   sequence (or batch of sequences). We use the ``GRU`` layer like this in
#   the ``encoder``. The reality is that under the hood, there is an
#   iterative process looping over each time step calculating hidden states.
#   Alternatively, you can run these modules one time-step at a time. In
#   this case, we manually loop over the sequences during the training
#   process like we must do for the ``decoder`` model. As long as you
#   maintain the correct conceptual model of these modules, implementing
#   sequential models can be very straightforward.

# %%
def train(input_variable, lengths, target_variable, mask, max_target_len, encoder, decoder, embedding,
          encoder_optimizer, decoder_optimizer, batch_size, clip, max_length=MAX_LENGTH):

    # Zero gradients
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    # Set device options
    input_variable = input_variable.to(device)
    target_variable = target_variable.to(device)
    mask = mask.to(device)
    # Lengths for rnn packing should always be on the cpu
    lengths = lengths.to("cpu")

    # Initialize variables
    loss = 0
    print_losses = []
    n_totals = 0

    # Forward pass through encoder
    encoder_outputs, encoder_hidden = encoder(input_variable, lengths)

    # Create initial decoder input (start with SOS tokens for each sentence)
    decoder_input = torch.LongTensor([[SOS_token for _ in range(batch_size)]])
    decoder_input = decoder_input.to(device)

    # Set initial decoder hidden state to the encoder's final hidden state
    decoder_hidden = encoder_hidden[:decoder.n_layers]

    # Determine if we are using teacher forcing this iteration
    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    # Forward batch of sequences through decoder one time step at a time
    if use_teacher_forcing:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # Teacher forcing: next input is current target
            decoder_input = target_variable[t].view(1, -1)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal
    else:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # No teacher forcing: next input is decoder's own current output
            _, topi = decoder_output.topk(1)
            decoder_input = torch.LongTensor([[topi[i][0] for i in range(batch_size)]])
            decoder_input = decoder_input.to(device)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal

    # Perform backpropatation
    loss.backward()

    # Clip gradients: gradients are modified in place
    _ = nn.utils.clip_grad_norm_(encoder.parameters(), clip)
    _ = nn.utils.clip_grad_norm_(decoder.parameters(), clip)

    # Adjust model weights
    encoder_optimizer.step()
    decoder_optimizer.step()

    return sum(print_losses) / n_totals

# %% [markdown]
# ### Training iterations
#
# It is finally time to tie the full training procedure together with the
# data. The ``trainIters`` function is responsible for running
# ``n_iterations`` of training given the passed models, optimizers, data,
# etc. This function is quite self explanatory, as we have done the heavy
# lifting with the ``train`` function.
#
# One thing to note is that when we save our model, we save a tarball
# containing the encoder and decoder state_dicts (parameters), the
# optimizers’ state_dicts, the loss, the iteration, etc. Saving the model
# in this way will give us the ultimate flexibility with the checkpoint.
# After loading a checkpoint, we will be able to use the model parameters
# to run inference, or we can continue training right where we left off.

# %%
def trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer, embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size, print_every, save_every, clip, corpus_name, loadFilename):

    # Load batches for each iteration
    training_batches = [batch2TrainData(voc, [random.choice(pairs) for _ in range(batch_size)])
                      for _ in range(n_iteration)]

    # Initializations
    print('Initializing ...')
    start_iteration = 1
    print_loss = 0
    if loadFilename:
        start_iteration = checkpoint['iteration'] + 1

    # Training loop
    print("Training...")
    total_loss = 0
    itr_counter = 0
    for iteration in range(start_iteration, n_iteration + 1):
        itr_counter += 1
        training_batch = training_batches[iteration - 1]
        # Extract fields from batch
        input_variable, lengths, target_variable, mask, max_target_len = training_batch

        # Run a training iteration with batch
        loss = train(input_variable, lengths, target_variable, mask, max_target_len, encoder,
                     decoder, embedding, encoder_optimizer, decoder_optimizer, batch_size, clip)
        total_loss += loss
        print_loss += loss

        # Print progress
        if iteration % print_every == 0:
            print_loss_avg = print_loss / print_every
            print("Iteration: {}; Percent complete: {:.1f}%; Average loss: {:.4f}".format(iteration, iteration / n_iteration * 100, print_loss_avg))
            print_loss = 0

        # Save checkpoint
        if (iteration % save_every == 0):
            directory = os.path.join(save_dir, model_name, corpus_name, '{}-{}_{}'.format(encoder_n_layers, decoder_n_layers, hidden_size))
            if not os.path.exists(directory):
                os.makedirs(directory)
            torch.save({
                'iteration': iteration,
                'en': encoder.state_dict(),
                'de': decoder.state_dict(),
                'en_opt': encoder_optimizer.state_dict(),
                'de_opt': decoder_optimizer.state_dict(),
                'loss': loss,
                'voc_dict': voc.__dict__,
                'embedding': embedding.state_dict()
            }, os.path.join(directory, '{}_{}.tar'.format(iteration, 'checkpoint')))
    return(total_loss/itr_counter)

# %% [markdown]
# ## Define Evaluation
#
# After training a model, we want to be able to talk to the bot ourselves.
# First, we must define how we want the model to decode the encoded input.
#
# ### Greedy decoding
#
# Greedy decoding is the decoding method that we use during training when
# we are **NOT** using teacher forcing. In other words, for each time
# step, we simply choose the word from ``decoder_output`` with the highest
# softmax value. This decoding method is optimal on a single time-step
# level.
#
# To facilitate the greedy decoding operation, we define a
# ``GreedySearchDecoder`` class. When run, an object of this class takes
# an input sequence (``input_seq``) of shape *(input_seq length, 1)*, a
# scalar input length (``input_length``) tensor, and a ``max_length`` to
# bound the response sentence length. The input sentence is evaluated
# using the following computational graph:
#
# **Computation Graph:**
#
#    1) Forward input through encoder model.
#    2) Prepare encoder's final hidden layer to be first hidden input to the decoder.
#    3) Initialize decoder's first input as SOS_token.
#    4) Initialize tensors to append decoded words to.
#    5) Iteratively decode one word token at a time:
#        a) Forward pass through decoder.
#        b) Obtain most likely word token and its softmax score.
#        c) Record token and score.
#        d) Prepare current token to be next decoder input.
#    6) Return collections of word tokens and scores.

# %%
class GreedySearchDecoder(nn.Module):
    def __init__(self, encoder, decoder):
        super(GreedySearchDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
    def forward(self, input_seq, input_length, max_length):
        # Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        decoder_hidden = encoder_hidden[:decoder.n_layers]
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        # Iteratively decode one word token at a time
        for _ in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            # Obtain most likely word token and its softmax score
            decoder_scores, decoder_input = torch.max(decoder_output, dim=1)
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores

# %% [markdown]
# ### Evaluate my text
#
# Now that we have our decoding method defined, we can write functions for
# evaluating a string input sentence. The ``evaluate`` function manages
# the low-level process of handling the input sentence. We first format
# the sentence as an input batch of word indexes with *batch_size==1*. We
# do this by converting the words of the sentence to their corresponding
# indexes, and transposing the dimensions to prepare the tensor for our
# models. We also create a ``lengths`` tensor which contains the length of
# our input sentence. In this case, ``lengths`` is scalar because we are
# only evaluating one sentence at a time (batch_size==1). Next, we obtain
# the decoded response sentence tensor using our ``GreedySearchDecoder``
# object (``searcher``). Finally, we convert the response’s indexes to
# words and return the list of decoded words.
#
# ``evaluateInput`` acts as the user interface for our chatbot. When
# called, an input text field will spawn in which we can enter our query
# sentence. After typing our input sentence and pressing *Enter*, our text
# is normalized in the same way as our training data, and is ultimately
# fed to the ``evaluate`` function to obtain a decoded output sentence. We
# loop this process, so we can keep chatting with our bot until we enter
# either “q” or “quit”.
#
# Finally, if a sentence is entered that contains a word that is not in
# the vocabulary, we handle this gracefully by printing an error message
# and prompting the user to enter another sentence.

# %%
def evaluate(encoder, decoder, searcher, voc, sentence, max_length=MAX_LENGTH):
    ### Format input sentence as a batch
    # words -> indexes
    indexes_batch = [indexesFromSentence(voc, sentence)]
    # Create lengths tensor
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    # Transpose dimensions of batch to match models' expectations
    input_batch = torch.LongTensor(indexes_batch).transpose(0, 1)
    # Use appropriate device
    input_batch = input_batch.to(device)
    lengths = lengths.to("cpu")
    # Decode sentence with searcher
    tokens, scores = searcher(input_batch, lengths, max_length)
    # indexes -> words
    decoded_words = [voc.index2word[token.item()] for token in tokens]
    return decoded_words


def evaluateInput(encoder, decoder, searcher, voc):
    input_sentence = ''
    while(1):
        try:
            # Get input sentence
            input_sentence = input('> ')
            # Check if it is quit case
            if input_sentence == 'q' or input_sentence == 'quit': break
            # Normalize sentence
            input_sentence = normalizeString(input_sentence)
            # Evaluate sentence
            output_words = evaluate(encoder, decoder, searcher, voc, input_sentence)
            # Format and print response sentence
            output_words[:] = [x for x in output_words if not (x == 'EOS' or x == 'PAD')]
            print('Bot:', ' '.join(output_words))

        except KeyError:
            print("Error: Encountered unknown word.")

# %% [markdown]
# ## Run Model
#
# Finally, it is time to run our model!
#
# Regardless of whether we want to train or test the chatbot model, we
# must initialize the individual encoder and decoder models. In the
# following block, we set our desired configurations, choose to start from
# scratch or set a checkpoint to load from, and build and initialize the
# models. Feel free to play with different model configurations to
# optimize performance.

# %%
# Configure models
model_name = 'cb_model'
attn_model = 'dot'
#attn_model = 'general'
#attn_model = 'concat'
hidden_size = 500
encoder_n_layers = 2
decoder_n_layers = 2
dropout = 0.1
batch_size = 64

# Set checkpoint to load from; set to None if starting from scratch
loadFilename = None
checkpoint_iter = 4000
#loadFilename = os.path.join(save_dir, model_name, corpus_name,
#                            '{}-{}_{}'.format(encoder_n_layers, decoder_n_layers, hidden_size),
#                            '{}_checkpoint.tar'.format(checkpoint_iter))


# Load model if a loadFilename is provided
if loadFilename:
    # If loading on same machine the model was trained on
    checkpoint = torch.load(loadFilename)
    # If loading a model trained on GPU to CPU
    #checkpoint = torch.load(loadFilename, map_location=torch.device('cpu'))
    encoder_sd = checkpoint['en']
    decoder_sd = checkpoint['de']
    encoder_optimizer_sd = checkpoint['en_opt']
    decoder_optimizer_sd = checkpoint['de_opt']
    embedding_sd = checkpoint['embedding']
    voc.__dict__ = checkpoint['voc_dict']


print('Building encoder and decoder ...')
# Initialize word embeddings
embedding = nn.Embedding(voc.num_words, hidden_size)
if loadFilename:
    embedding.load_state_dict(embedding_sd)
# Initialize encoder & decoder models
encoder = EncoderRNN(hidden_size, embedding, encoder_n_layers, dropout)
decoder = LuongAttnDecoderRNN(attn_model, embedding, hidden_size, voc.num_words, decoder_n_layers, dropout)
if loadFilename:
    encoder.load_state_dict(encoder_sd)
    decoder.load_state_dict(decoder_sd)
# Use appropriate device
encoder = encoder.to(device)
decoder = decoder.to(device)
print('Models built and ready to go!')
# Out:
# Building encoder and decoder ...
# Models built and ready to go!

# %% [markdown]
# ### Run Training
#
# Run the following block if you want to train the model.
#
# First we set training parameters, then we initialize our optimizers, and
# finally we call the ``trainIters`` function to run our training
# iterations.

# %%
# Configure training/optimization
clip = 50.0
teacher_forcing_ratio = 1.0
learning_rate = 0.0001
decoder_learning_ratio = 5.0
n_iteration = 4000
print_every = 1
save_every = 500

# Ensure dropout layers are in train mode
encoder.train()
decoder.train()

# Initialize optimizers
print('Building optimizers ...')
encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)
if loadFilename:
    encoder_optimizer.load_state_dict(encoder_optimizer_sd)
    decoder_optimizer.load_state_dict(decoder_optimizer_sd)

# If you have cuda, configure cuda to call
for state in encoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.cuda()

for state in decoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.cuda()

# Run training iterations
print("Starting Training!")
trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer,
           embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size,
           print_every, save_every, clip, corpus_name, loadFilename)
# Out:
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 1; Percent complete: 0.0%; Average loss: 8.9737
# Iteration: 2; Percent complete: 0.1%; Average loss: 8.8443
# Iteration: 3; Percent complete: 0.1%; Average loss: 8.6283
# Iteration: 4; Percent complete: 0.1%; Average loss: 8.3634
# Iteration: 5; Percent complete: 0.1%; Average loss: 7.8782
# Iteration: 6; Percent complete: 0.1%; Average loss: 7.2911
# Iteration: 7; Percent complete: 0.2%; Average loss: 6.7550
# Iteration: 8; Percent complete: 0.2%; Average loss: 6.9870
# Iteration: 9; Percent complete: 0.2%; Average loss: 6.8889
# Iteration: 10; Percent complete: 0.2%; Average loss: 6.3766
# Iteration: 11; Percent complete: 0.3%; Average loss: 6.2924
# Iteration: 12; Percent complete: 0.3%; Average loss: 5.9520
# Iteration: 13; Percent complete: 0.3%; Average loss: 5.8781
# Iteration: 14; Percent complete: 0.4%; Average loss: 5.5389
# Iteration: 15; Percent complete: 0.4%; Average loss: 5.4942
# Iteration: 16; Percent complete: 0.4%; Average loss: 5.3129
# Iteration: 17; Percent complete: 0.4%; Average loss: 4.8701
# Iteration: 18; Percent complete: 0.4%; Average loss: 5.0988
# Iteration: 19; Percent complete: 0.5%; Average loss: 5.1040
# Iteration: 20; Percent complete: 0.5%; Average loss: 5.0130
# Iteration: 21; Percent complete: 0.5%; Average loss: 4.8993
# Iteration: 22; Percent complete: 0.5%; Average loss: 4.8532
# Iteration: 23; Percent complete: 0.6%; Average loss: 4.9226
# Iteration: 24; Percent complete: 0.6%; Average loss: 4.7331
# Iteration: 25; Percent complete: 0.6%; Average loss: 4.6841
# Iteration: 26; Percent complete: 0.7%; Average loss: 5.0332
# Iteration: 27; Percent complete: 0.7%; Average loss: 4.9315
# Iteration: 28; Percent complete: 0.7%; Average loss: 4.7519
# Iteration: 29; Percent complete: 0.7%; Average loss: 4.9758
# Iteration: 30; Percent complete: 0.8%; Average loss: 4.9096
# Iteration: 31; Percent complete: 0.8%; Average loss: 4.6802
# Iteration: 32; Percent complete: 0.8%; Average loss: 4.9764
# Iteration: 33; Percent complete: 0.8%; Average loss: 4.8889
# Iteration: 34; Percent complete: 0.9%; Average loss: 4.8556
# Iteration: 35; Percent complete: 0.9%; Average loss: 5.0116
# Iteration: 36; Percent complete: 0.9%; Average loss: 4.5846
# Iteration: 37; Percent complete: 0.9%; Average loss: 4.8585
# Iteration: 38; Percent complete: 0.9%; Average loss: 4.8539
# Iteration: 39; Percent complete: 1.0%; Average loss: 4.7997
# Iteration: 40; Percent complete: 1.0%; Average loss: 4.8341
# Iteration: 41; Percent complete: 1.0%; Average loss: 4.8184
# Iteration: 42; Percent complete: 1.1%; Average loss: 4.7404
# Iteration: 43; Percent complete: 1.1%; Average loss: 4.7355
# Iteration: 44; Percent complete: 1.1%; Average loss: 4.5275
# Iteration: 45; Percent complete: 1.1%; Average loss: 4.8196
# Iteration: 46; Percent complete: 1.1%; Average loss: 4.7870
# Iteration: 47; Percent complete: 1.2%; Average loss: 4.5966
# Iteration: 48; Percent complete: 1.2%; Average loss: 4.7892
# Iteration: 49; Percent complete: 1.2%; Average loss: 4.9060
# Iteration: 50; Percent complete: 1.2%; Average loss: 4.3714
# Iteration: 51; Percent complete: 1.3%; Average loss: 4.6231
# Iteration: 52; Percent complete: 1.3%; Average loss: 4.6079
# Iteration: 53; Percent complete: 1.3%; Average loss: 4.5692
# Iteration: 54; Percent complete: 1.4%; Average loss: 4.5343
# Iteration: 55; Percent complete: 1.4%; Average loss: 4.5660
# Iteration: 56; Percent complete: 1.4%; Average loss: 4.5419
# Iteration: 57; Percent complete: 1.4%; Average loss: 4.6301
# Iteration: 58; Percent complete: 1.5%; Average loss: 4.5828
# Iteration: 59; Percent complete: 1.5%; Average loss: 4.5729
# Iteration: 60; Percent complete: 1.5%; Average loss: 4.5639
# Iteration: 61; Percent complete: 1.5%; Average loss: 4.5253
# Iteration: 62; Percent complete: 1.6%; Average loss: 4.8448
# Iteration: 63; Percent complete: 1.6%; Average loss: 4.5198
# Iteration: 64; Percent complete: 1.6%; Average loss: 4.6388
# Iteration: 65; Percent complete: 1.6%; Average loss: 4.1029
# Iteration: 66; Percent complete: 1.7%; Average loss: 4.6868
# Iteration: 67; Percent complete: 1.7%; Average loss: 4.6071
# Iteration: 68; Percent complete: 1.7%; Average loss: 4.6252
# Iteration: 69; Percent complete: 1.7%; Average loss: 4.4248
# Iteration: 70; Percent complete: 1.8%; Average loss: 4.5983
# Iteration: 71; Percent complete: 1.8%; Average loss: 4.4587
# Iteration: 72; Percent complete: 1.8%; Average loss: 4.5273
# Iteration: 73; Percent complete: 1.8%; Average loss: 4.5325
# Iteration: 74; Percent complete: 1.8%; Average loss: 4.6755
# Iteration: 75; Percent complete: 1.9%; Average loss: 4.5822
# Iteration: 76; Percent complete: 1.9%; Average loss: 4.5143
# Iteration: 77; Percent complete: 1.9%; Average loss: 4.5306
# Iteration: 78; Percent complete: 1.9%; Average loss: 4.4965
# Iteration: 79; Percent complete: 2.0%; Average loss: 4.4724
# Iteration: 80; Percent complete: 2.0%; Average loss: 4.4771
# Iteration: 81; Percent complete: 2.0%; Average loss: 4.4700
# Iteration: 82; Percent complete: 2.1%; Average loss: 4.4988
# Iteration: 83; Percent complete: 2.1%; Average loss: 4.6131
# Iteration: 84; Percent complete: 2.1%; Average loss: 4.4094
# Iteration: 85; Percent complete: 2.1%; Average loss: 4.3551
# Iteration: 86; Percent complete: 2.1%; Average loss: 4.4791
# Iteration: 87; Percent complete: 2.2%; Average loss: 4.3261
# Iteration: 88; Percent complete: 2.2%; Average loss: 4.4743
# Iteration: 89; Percent complete: 2.2%; Average loss: 4.5670
# Iteration: 90; Percent complete: 2.2%; Average loss: 4.2931
# Iteration: 91; Percent complete: 2.3%; Average loss: 4.4881
# Iteration: 92; Percent complete: 2.3%; Average loss: 4.5902
# Iteration: 93; Percent complete: 2.3%; Average loss: 4.5548
# Iteration: 94; Percent complete: 2.4%; Average loss: 4.3988
# Iteration: 95; Percent complete: 2.4%; Average loss: 4.2746
# Iteration: 96; Percent complete: 2.4%; Average loss: 4.3042
# Iteration: 97; Percent complete: 2.4%; Average loss: 4.5706
# Iteration: 98; Percent complete: 2.5%; Average loss: 4.4268
# Iteration: 99; Percent complete: 2.5%; Average loss: 4.4736
# Iteration: 100; Percent complete: 2.5%; Average loss: 4.5603
# Iteration: 101; Percent complete: 2.5%; Average loss: 4.3290
# Iteration: 102; Percent complete: 2.5%; Average loss: 4.4306
# Iteration: 103; Percent complete: 2.6%; Average loss: 4.1899
# Iteration: 104; Percent complete: 2.6%; Average loss: 4.5176
# Iteration: 105; Percent complete: 2.6%; Average loss: 4.4510
# Iteration: 106; Percent complete: 2.6%; Average loss: 4.4592
# Iteration: 107; Percent complete: 2.7%; Average loss: 4.3111
# Iteration: 108; Percent complete: 2.7%; Average loss: 4.3444
# Iteration: 109; Percent complete: 2.7%; Average loss: 4.2575
# Iteration: 110; Percent complete: 2.8%; Average loss: 4.6127
# Iteration: 111; Percent complete: 2.8%; Average loss: 4.4496
# Iteration: 112; Percent complete: 2.8%; Average loss: 4.4356
# Iteration: 113; Percent complete: 2.8%; Average loss: 4.6507
# Iteration: 114; Percent complete: 2.9%; Average loss: 4.1279
# Iteration: 115; Percent complete: 2.9%; Average loss: 4.3902
# Iteration: 116; Percent complete: 2.9%; Average loss: 4.3173
# Iteration: 117; Percent complete: 2.9%; Average loss: 4.5804
# Iteration: 118; Percent complete: 2.9%; Average loss: 4.2197
# Iteration: 119; Percent complete: 3.0%; Average loss: 4.1533
# Iteration: 120; Percent complete: 3.0%; Average loss: 4.4104
# Iteration: 121; Percent complete: 3.0%; Average loss: 4.4261
# Iteration: 122; Percent complete: 3.0%; Average loss: 4.4362
# Iteration: 123; Percent complete: 3.1%; Average loss: 4.4014
# Iteration: 124; Percent complete: 3.1%; Average loss: 4.3780
# Iteration: 125; Percent complete: 3.1%; Average loss: 4.2730
# Iteration: 126; Percent complete: 3.1%; Average loss: 4.2890
# Iteration: 127; Percent complete: 3.2%; Average loss: 4.5251
# Iteration: 128; Percent complete: 3.2%; Average loss: 4.4760
# Iteration: 129; Percent complete: 3.2%; Average loss: 4.2048
# Iteration: 130; Percent complete: 3.2%; Average loss: 4.2851
# Iteration: 131; Percent complete: 3.3%; Average loss: 4.2071
# Iteration: 132; Percent complete: 3.3%; Average loss: 4.2966
# Iteration: 133; Percent complete: 3.3%; Average loss: 4.3955
# Iteration: 134; Percent complete: 3.4%; Average loss: 4.4955
# Iteration: 135; Percent complete: 3.4%; Average loss: 4.3685
# Iteration: 136; Percent complete: 3.4%; Average loss: 4.1945
# Iteration: 137; Percent complete: 3.4%; Average loss: 4.2121
# Iteration: 138; Percent complete: 3.5%; Average loss: 4.4170
# Iteration: 139; Percent complete: 3.5%; Average loss: 3.8448
# Iteration: 140; Percent complete: 3.5%; Average loss: 4.2610
# Iteration: 141; Percent complete: 3.5%; Average loss: 4.2775
# Iteration: 142; Percent complete: 3.5%; Average loss: 4.2324
# Iteration: 143; Percent complete: 3.6%; Average loss: 4.4926
# Iteration: 144; Percent complete: 3.6%; Average loss: 4.4945
# Iteration: 145; Percent complete: 3.6%; Average loss: 4.1583
# Iteration: 146; Percent complete: 3.6%; Average loss: 4.3149
# Iteration: 147; Percent complete: 3.7%; Average loss: 4.3816
# Iteration: 148; Percent complete: 3.7%; Average loss: 4.4292
# Iteration: 149; Percent complete: 3.7%; Average loss: 4.5183
# Iteration: 150; Percent complete: 3.8%; Average loss: 4.1252
# Iteration: 151; Percent complete: 3.8%; Average loss: 4.2234
# Iteration: 152; Percent complete: 3.8%; Average loss: 4.1558
# Iteration: 153; Percent complete: 3.8%; Average loss: 4.4266
# Iteration: 154; Percent complete: 3.9%; Average loss: 4.2575
# Iteration: 155; Percent complete: 3.9%; Average loss: 4.5120
# Iteration: 156; Percent complete: 3.9%; Average loss: 4.3065
# Iteration: 157; Percent complete: 3.9%; Average loss: 4.2055
# Iteration: 158; Percent complete: 4.0%; Average loss: 4.1284
# Iteration: 159; Percent complete: 4.0%; Average loss: 4.3953
# Iteration: 160; Percent complete: 4.0%; Average loss: 4.1351
# Iteration: 161; Percent complete: 4.0%; Average loss: 4.1295
# Iteration: 162; Percent complete: 4.0%; Average loss: 4.1944
# Iteration: 163; Percent complete: 4.1%; Average loss: 4.4406
# Iteration: 164; Percent complete: 4.1%; Average loss: 4.1646
# Iteration: 165; Percent complete: 4.1%; Average loss: 3.9936
# Iteration: 166; Percent complete: 4.2%; Average loss: 4.1787
# Iteration: 167; Percent complete: 4.2%; Average loss: 4.1921
# Iteration: 168; Percent complete: 4.2%; Average loss: 4.2461
# Iteration: 169; Percent complete: 4.2%; Average loss: 4.3150
# Iteration: 170; Percent complete: 4.2%; Average loss: 3.9896
# Iteration: 171; Percent complete: 4.3%; Average loss: 4.0161
# Iteration: 172; Percent complete: 4.3%; Average loss: 4.3022
# Iteration: 173; Percent complete: 4.3%; Average loss: 4.2332
# Iteration: 174; Percent complete: 4.3%; Average loss: 3.9399
# Iteration: 175; Percent complete: 4.4%; Average loss: 4.2770
# Iteration: 176; Percent complete: 4.4%; Average loss: 4.2784
# Iteration: 177; Percent complete: 4.4%; Average loss: 4.1686
# Iteration: 178; Percent complete: 4.5%; Average loss: 4.2159
# Iteration: 179; Percent complete: 4.5%; Average loss: 3.9970
# Iteration: 180; Percent complete: 4.5%; Average loss: 3.9250
# Iteration: 181; Percent complete: 4.5%; Average loss: 4.1963
# Iteration: 182; Percent complete: 4.5%; Average loss: 4.0163
# Iteration: 183; Percent complete: 4.6%; Average loss: 4.3231
# Iteration: 184; Percent complete: 4.6%; Average loss: 4.3237
# Iteration: 185; Percent complete: 4.6%; Average loss: 4.2635
# Iteration: 186; Percent complete: 4.7%; Average loss: 4.1990
# Iteration: 187; Percent complete: 4.7%; Average loss: 4.0329
# Iteration: 188; Percent complete: 4.7%; Average loss: 4.2436
# Iteration: 189; Percent complete: 4.7%; Average loss: 4.1516
# Iteration: 190; Percent complete: 4.8%; Average loss: 4.0877
# Iteration: 191; Percent complete: 4.8%; Average loss: 4.0169
# Iteration: 192; Percent complete: 4.8%; Average loss: 4.0856
# Iteration: 193; Percent complete: 4.8%; Average loss: 3.9213
# Iteration: 194; Percent complete: 4.9%; Average loss: 4.0830
# Iteration: 195; Percent complete: 4.9%; Average loss: 3.9744
# Iteration: 196; Percent complete: 4.9%; Average loss: 4.1530
# Iteration: 197; Percent complete: 4.9%; Average loss: 4.2879
# Iteration: 198; Percent complete: 5.0%; Average loss: 4.3856
# Iteration: 199; Percent complete: 5.0%; Average loss: 4.0249
# Iteration: 200; Percent complete: 5.0%; Average loss: 4.1198
# Iteration: 201; Percent complete: 5.0%; Average loss: 4.1664
# Iteration: 202; Percent complete: 5.1%; Average loss: 4.2587
# Iteration: 203; Percent complete: 5.1%; Average loss: 3.9787
# Iteration: 204; Percent complete: 5.1%; Average loss: 4.0272
# Iteration: 205; Percent complete: 5.1%; Average loss: 3.9334
# Iteration: 206; Percent complete: 5.1%; Average loss: 4.4938
# Iteration: 207; Percent complete: 5.2%; Average loss: 4.0352
# Iteration: 208; Percent complete: 5.2%; Average loss: 4.1880
# Iteration: 209; Percent complete: 5.2%; Average loss: 4.0283
# Iteration: 210; Percent complete: 5.2%; Average loss: 3.9686
# Iteration: 211; Percent complete: 5.3%; Average loss: 3.9695
# Iteration: 212; Percent complete: 5.3%; Average loss: 4.1279
# Iteration: 213; Percent complete: 5.3%; Average loss: 4.1056
# Iteration: 214; Percent complete: 5.3%; Average loss: 4.0866
# Iteration: 215; Percent complete: 5.4%; Average loss: 4.1879
# Iteration: 216; Percent complete: 5.4%; Average loss: 4.1068
# Iteration: 217; Percent complete: 5.4%; Average loss: 4.4160
# Iteration: 218; Percent complete: 5.5%; Average loss: 4.3017
# Iteration: 219; Percent complete: 5.5%; Average loss: 3.9784
# Iteration: 220; Percent complete: 5.5%; Average loss: 4.0586
# Iteration: 221; Percent complete: 5.5%; Average loss: 3.9153
# Iteration: 222; Percent complete: 5.5%; Average loss: 4.0272
# Iteration: 223; Percent complete: 5.6%; Average loss: 4.0244
# Iteration: 224; Percent complete: 5.6%; Average loss: 4.1435
# Iteration: 225; Percent complete: 5.6%; Average loss: 3.9747
# Iteration: 226; Percent complete: 5.7%; Average loss: 3.8573
# Iteration: 227; Percent complete: 5.7%; Average loss: 3.8330
# Iteration: 228; Percent complete: 5.7%; Average loss: 4.0774
# Iteration: 229; Percent complete: 5.7%; Average loss: 4.2780
# Iteration: 230; Percent complete: 5.8%; Average loss: 3.8380
# Iteration: 231; Percent complete: 5.8%; Average loss: 4.1576
# Iteration: 232; Percent complete: 5.8%; Average loss: 4.1490
# Iteration: 233; Percent complete: 5.8%; Average loss: 4.0916
# Iteration: 234; Percent complete: 5.9%; Average loss: 3.9981
# Iteration: 235; Percent complete: 5.9%; Average loss: 4.0233
# Iteration: 236; Percent complete: 5.9%; Average loss: 4.0524
# Iteration: 237; Percent complete: 5.9%; Average loss: 3.9491
# Iteration: 238; Percent complete: 5.9%; Average loss: 3.8853
# Iteration: 239; Percent complete: 6.0%; Average loss: 4.0924
# Iteration: 240; Percent complete: 6.0%; Average loss: 4.1690
# Iteration: 241; Percent complete: 6.0%; Average loss: 3.9763
# Iteration: 242; Percent complete: 6.0%; Average loss: 3.9581
# Iteration: 243; Percent complete: 6.1%; Average loss: 4.2073
# Iteration: 244; Percent complete: 6.1%; Average loss: 4.0353
# Iteration: 245; Percent complete: 6.1%; Average loss: 3.8634
# Iteration: 246; Percent complete: 6.2%; Average loss: 3.8705
# Iteration: 247; Percent complete: 6.2%; Average loss: 4.1953
# Iteration: 248; Percent complete: 6.2%; Average loss: 4.1560
# Iteration: 249; Percent complete: 6.2%; Average loss: 4.1988
# Iteration: 250; Percent complete: 6.2%; Average loss: 3.9065
# Iteration: 251; Percent complete: 6.3%; Average loss: 3.9962
# Iteration: 252; Percent complete: 6.3%; Average loss: 4.0341
# Iteration: 253; Percent complete: 6.3%; Average loss: 4.1754
# Iteration: 254; Percent complete: 6.3%; Average loss: 3.8340
# Iteration: 255; Percent complete: 6.4%; Average loss: 3.7491
# Iteration: 256; Percent complete: 6.4%; Average loss: 4.0747
# Iteration: 257; Percent complete: 6.4%; Average loss: 4.3126
# Iteration: 258; Percent complete: 6.5%; Average loss: 3.9817
# Iteration: 259; Percent complete: 6.5%; Average loss: 3.8286
# Iteration: 260; Percent complete: 6.5%; Average loss: 3.7851
# Iteration: 261; Percent complete: 6.5%; Average loss: 3.9185
# Iteration: 262; Percent complete: 6.6%; Average loss: 3.7364
# Iteration: 263; Percent complete: 6.6%; Average loss: 3.7568
# Iteration: 264; Percent complete: 6.6%; Average loss: 3.8789
# Iteration: 265; Percent complete: 6.6%; Average loss: 4.1391
# Iteration: 266; Percent complete: 6.7%; Average loss: 3.8600
# Iteration: 267; Percent complete: 6.7%; Average loss: 4.0544
# Iteration: 268; Percent complete: 6.7%; Average loss: 4.0362
# Iteration: 269; Percent complete: 6.7%; Average loss: 3.8413
# Iteration: 270; Percent complete: 6.8%; Average loss: 4.2266
# Iteration: 271; Percent complete: 6.8%; Average loss: 3.8290
# Iteration: 272; Percent complete: 6.8%; Average loss: 3.9760
# Iteration: 273; Percent complete: 6.8%; Average loss: 4.1097
# Iteration: 274; Percent complete: 6.9%; Average loss: 3.6522
# Iteration: 275; Percent complete: 6.9%; Average loss: 3.9548
# Iteration: 276; Percent complete: 6.9%; Average loss: 4.0514
# Iteration: 277; Percent complete: 6.9%; Average loss: 3.8992
# Iteration: 278; Percent complete: 7.0%; Average loss: 3.9446
# Iteration: 279; Percent complete: 7.0%; Average loss: 4.2132
# Iteration: 280; Percent complete: 7.0%; Average loss: 4.2726
# Iteration: 281; Percent complete: 7.0%; Average loss: 3.9059
# Iteration: 282; Percent complete: 7.0%; Average loss: 3.9182
# Iteration: 283; Percent complete: 7.1%; Average loss: 4.0770
# Iteration: 284; Percent complete: 7.1%; Average loss: 3.8168
# Iteration: 285; Percent complete: 7.1%; Average loss: 4.1421
# Iteration: 286; Percent complete: 7.1%; Average loss: 3.7920
# Iteration: 287; Percent complete: 7.2%; Average loss: 3.9017
# Iteration: 288; Percent complete: 7.2%; Average loss: 4.1422
# Iteration: 289; Percent complete: 7.2%; Average loss: 3.9651
# Iteration: 290; Percent complete: 7.2%; Average loss: 4.2537
# Iteration: 291; Percent complete: 7.3%; Average loss: 4.2209
# Iteration: 292; Percent complete: 7.3%; Average loss: 4.1194
# Iteration: 293; Percent complete: 7.3%; Average loss: 4.3022
# Iteration: 294; Percent complete: 7.3%; Average loss: 4.1332
# Iteration: 295; Percent complete: 7.4%; Average loss: 4.1084
# Iteration: 296; Percent complete: 7.4%; Average loss: 3.8676
# Iteration: 297; Percent complete: 7.4%; Average loss: 3.9145
# Iteration: 298; Percent complete: 7.4%; Average loss: 3.8832
# Iteration: 299; Percent complete: 7.5%; Average loss: 4.1425
# Iteration: 300; Percent complete: 7.5%; Average loss: 3.9027
# Iteration: 301; Percent complete: 7.5%; Average loss: 3.9779
# Iteration: 302; Percent complete: 7.5%; Average loss: 3.6840
# Iteration: 303; Percent complete: 7.6%; Average loss: 4.0844
# Iteration: 304; Percent complete: 7.6%; Average loss: 3.7725
# Iteration: 305; Percent complete: 7.6%; Average loss: 3.8346
# Iteration: 306; Percent complete: 7.6%; Average loss: 3.7675
# Iteration: 307; Percent complete: 7.7%; Average loss: 3.8661
# Iteration: 308; Percent complete: 7.7%; Average loss: 3.7236
# Iteration: 309; Percent complete: 7.7%; Average loss: 3.7252
# Iteration: 310; Percent complete: 7.8%; Average loss: 4.1778
# Iteration: 311; Percent complete: 7.8%; Average loss: 3.6635
# Iteration: 312; Percent complete: 7.8%; Average loss: 3.8163
# Iteration: 313; Percent complete: 7.8%; Average loss: 3.8962
# Iteration: 314; Percent complete: 7.8%; Average loss: 3.8921
# Iteration: 315; Percent complete: 7.9%; Average loss: 3.8242
# Iteration: 316; Percent complete: 7.9%; Average loss: 3.7822
# Iteration: 317; Percent complete: 7.9%; Average loss: 4.2214
# Iteration: 318; Percent complete: 8.0%; Average loss: 3.9625
# Iteration: 319; Percent complete: 8.0%; Average loss: 4.0033
# Iteration: 320; Percent complete: 8.0%; Average loss: 4.0353
# Iteration: 321; Percent complete: 8.0%; Average loss: 4.1568
# Iteration: 322; Percent complete: 8.1%; Average loss: 3.7114
# Iteration: 323; Percent complete: 8.1%; Average loss: 4.0358
# Iteration: 324; Percent complete: 8.1%; Average loss: 4.0703
# Iteration: 325; Percent complete: 8.1%; Average loss: 3.8173
# Iteration: 326; Percent complete: 8.2%; Average loss: 3.8226
# Iteration: 327; Percent complete: 8.2%; Average loss: 3.8059
# Iteration: 328; Percent complete: 8.2%; Average loss: 3.5270
# Iteration: 329; Percent complete: 8.2%; Average loss: 3.7061
# Iteration: 330; Percent complete: 8.2%; Average loss: 3.7797
# Iteration: 331; Percent complete: 8.3%; Average loss: 4.0781
# Iteration: 332; Percent complete: 8.3%; Average loss: 3.8647
# Iteration: 333; Percent complete: 8.3%; Average loss: 3.9756
# Iteration: 334; Percent complete: 8.3%; Average loss: 3.9039
# Iteration: 335; Percent complete: 8.4%; Average loss: 3.8936
# Iteration: 336; Percent complete: 8.4%; Average loss: 3.8957
# Iteration: 337; Percent complete: 8.4%; Average loss: 3.8835
# Iteration: 338; Percent complete: 8.5%; Average loss: 4.1138
# Iteration: 339; Percent complete: 8.5%; Average loss: 3.9290
# Iteration: 340; Percent complete: 8.5%; Average loss: 3.8198
# Iteration: 341; Percent complete: 8.5%; Average loss: 3.9236
# Iteration: 342; Percent complete: 8.6%; Average loss: 3.8018
# Iteration: 343; Percent complete: 8.6%; Average loss: 4.0398
# Iteration: 344; Percent complete: 8.6%; Average loss: 3.9309
# Iteration: 345; Percent complete: 8.6%; Average loss: 3.8718
# Iteration: 346; Percent complete: 8.6%; Average loss: 3.8789
# Iteration: 347; Percent complete: 8.7%; Average loss: 3.9519
# Iteration: 348; Percent complete: 8.7%; Average loss: 3.9570
# Iteration: 349; Percent complete: 8.7%; Average loss: 3.8442
# Iteration: 350; Percent complete: 8.8%; Average loss: 3.7121
# Iteration: 351; Percent complete: 8.8%; Average loss: 4.0340
# Iteration: 352; Percent complete: 8.8%; Average loss: 4.0109
# Iteration: 353; Percent complete: 8.8%; Average loss: 3.9442
# Iteration: 354; Percent complete: 8.8%; Average loss: 3.9865
# Iteration: 355; Percent complete: 8.9%; Average loss: 3.5777
# Iteration: 356; Percent complete: 8.9%; Average loss: 3.8215
# Iteration: 357; Percent complete: 8.9%; Average loss: 3.7571
# Iteration: 358; Percent complete: 8.9%; Average loss: 3.9803
# Iteration: 359; Percent complete: 9.0%; Average loss: 3.8260
# Iteration: 360; Percent complete: 9.0%; Average loss: 3.8651
# Iteration: 361; Percent complete: 9.0%; Average loss: 3.9781
# Iteration: 362; Percent complete: 9.0%; Average loss: 3.9585
# Iteration: 363; Percent complete: 9.1%; Average loss: 3.8721
# Iteration: 364; Percent complete: 9.1%; Average loss: 3.8852
# Iteration: 365; Percent complete: 9.1%; Average loss: 3.9490
# Iteration: 366; Percent complete: 9.2%; Average loss: 3.8332
# Iteration: 367; Percent complete: 9.2%; Average loss: 4.0709
# Iteration: 368; Percent complete: 9.2%; Average loss: 3.7348
# Iteration: 369; Percent complete: 9.2%; Average loss: 3.9051
# Iteration: 370; Percent complete: 9.2%; Average loss: 3.7168
# Iteration: 371; Percent complete: 9.3%; Average loss: 3.9101
# Iteration: 372; Percent complete: 9.3%; Average loss: 3.8843
# Iteration: 373; Percent complete: 9.3%; Average loss: 3.6677
# Iteration: 374; Percent complete: 9.3%; Average loss: 3.9508
# Iteration: 375; Percent complete: 9.4%; Average loss: 3.9277
# Iteration: 376; Percent complete: 9.4%; Average loss: 3.7127
# Iteration: 377; Percent complete: 9.4%; Average loss: 3.8719
# Iteration: 378; Percent complete: 9.4%; Average loss: 3.7889
# Iteration: 379; Percent complete: 9.5%; Average loss: 3.8621
# Iteration: 380; Percent complete: 9.5%; Average loss: 3.7290
# Iteration: 381; Percent complete: 9.5%; Average loss: 4.0174
# Iteration: 382; Percent complete: 9.6%; Average loss: 3.7323
# Iteration: 383; Percent complete: 9.6%; Average loss: 3.8238
# Iteration: 384; Percent complete: 9.6%; Average loss: 3.8780
# Iteration: 385; Percent complete: 9.6%; Average loss: 4.1575
# Iteration: 386; Percent complete: 9.7%; Average loss: 3.9460
# Iteration: 387; Percent complete: 9.7%; Average loss: 3.7254
# Iteration: 388; Percent complete: 9.7%; Average loss: 3.9648
# Iteration: 389; Percent complete: 9.7%; Average loss: 3.4821
# Iteration: 390; Percent complete: 9.8%; Average loss: 3.5611
# Iteration: 391; Percent complete: 9.8%; Average loss: 3.9786
# Iteration: 392; Percent complete: 9.8%; Average loss: 3.7312
# Iteration: 393; Percent complete: 9.8%; Average loss: 3.7307
# Iteration: 394; Percent complete: 9.8%; Average loss: 3.8781
# Iteration: 395; Percent complete: 9.9%; Average loss: 3.6998
# Iteration: 396; Percent complete: 9.9%; Average loss: 3.7985
# Iteration: 397; Percent complete: 9.9%; Average loss: 3.8559
# Iteration: 398; Percent complete: 10.0%; Average loss: 3.7547
# Iteration: 399; Percent complete: 10.0%; Average loss: 3.7074
# Iteration: 400; Percent complete: 10.0%; Average loss: 3.8987
# Iteration: 401; Percent complete: 10.0%; Average loss: 3.8943
# Iteration: 402; Percent complete: 10.1%; Average loss: 3.9758
# Iteration: 403; Percent complete: 10.1%; Average loss: 3.9383
# Iteration: 404; Percent complete: 10.1%; Average loss: 3.6886
# Iteration: 405; Percent complete: 10.1%; Average loss: 3.8037
# Iteration: 406; Percent complete: 10.2%; Average loss: 3.8310
# Iteration: 407; Percent complete: 10.2%; Average loss: 3.5734
# Iteration: 408; Percent complete: 10.2%; Average loss: 3.7498
# Iteration: 409; Percent complete: 10.2%; Average loss: 3.7571
# Iteration: 410; Percent complete: 10.2%; Average loss: 3.9547
# Iteration: 411; Percent complete: 10.3%; Average loss: 3.5689
# Iteration: 412; Percent complete: 10.3%; Average loss: 3.8199
# Iteration: 413; Percent complete: 10.3%; Average loss: 3.8164
# Iteration: 414; Percent complete: 10.3%; Average loss: 3.8573
# Iteration: 415; Percent complete: 10.4%; Average loss: 3.8286
# Iteration: 416; Percent complete: 10.4%; Average loss: 3.6639
# Iteration: 417; Percent complete: 10.4%; Average loss: 4.0121
# Iteration: 418; Percent complete: 10.4%; Average loss: 3.8912
# Iteration: 419; Percent complete: 10.5%; Average loss: 3.9009
# Iteration: 420; Percent complete: 10.5%; Average loss: 3.5801
# Iteration: 421; Percent complete: 10.5%; Average loss: 3.6328
# Iteration: 422; Percent complete: 10.5%; Average loss: 3.7359
# Iteration: 423; Percent complete: 10.6%; Average loss: 3.8521
# Iteration: 424; Percent complete: 10.6%; Average loss: 3.5810
# Iteration: 425; Percent complete: 10.6%; Average loss: 3.5925
# Iteration: 426; Percent complete: 10.7%; Average loss: 3.8404
# Iteration: 427; Percent complete: 10.7%; Average loss: 3.7967
# Iteration: 428; Percent complete: 10.7%; Average loss: 3.6843
# Iteration: 429; Percent complete: 10.7%; Average loss: 3.6704
# Iteration: 430; Percent complete: 10.8%; Average loss: 3.9143
# Iteration: 431; Percent complete: 10.8%; Average loss: 3.9868
# Iteration: 432; Percent complete: 10.8%; Average loss: 3.8809
# Iteration: 433; Percent complete: 10.8%; Average loss: 3.6794
# Iteration: 434; Percent complete: 10.8%; Average loss: 3.8652
# Iteration: 435; Percent complete: 10.9%; Average loss: 3.9303
# Iteration: 436; Percent complete: 10.9%; Average loss: 4.0201
# Iteration: 437; Percent complete: 10.9%; Average loss: 3.9963
# Iteration: 438; Percent complete: 10.9%; Average loss: 3.6395
# Iteration: 439; Percent complete: 11.0%; Average loss: 3.8529
# Iteration: 440; Percent complete: 11.0%; Average loss: 3.7688
# Iteration: 441; Percent complete: 11.0%; Average loss: 3.7443
# Iteration: 442; Percent complete: 11.1%; Average loss: 3.8480
# Iteration: 443; Percent complete: 11.1%; Average loss: 3.5501
# Iteration: 444; Percent complete: 11.1%; Average loss: 3.9154
# Iteration: 445; Percent complete: 11.1%; Average loss: 3.8798
# Iteration: 446; Percent complete: 11.2%; Average loss: 3.6478
# Iteration: 447; Percent complete: 11.2%; Average loss: 3.8609
# Iteration: 448; Percent complete: 11.2%; Average loss: 3.5212
# Iteration: 449; Percent complete: 11.2%; Average loss: 3.5836
# Iteration: 450; Percent complete: 11.2%; Average loss: 3.4327
# Iteration: 451; Percent complete: 11.3%; Average loss: 3.7562
# Iteration: 452; Percent complete: 11.3%; Average loss: 3.9014
# Iteration: 453; Percent complete: 11.3%; Average loss: 3.9730
# Iteration: 454; Percent complete: 11.3%; Average loss: 3.8889
# Iteration: 455; Percent complete: 11.4%; Average loss: 3.6821
# Iteration: 456; Percent complete: 11.4%; Average loss: 3.9457
# Iteration: 457; Percent complete: 11.4%; Average loss: 3.8264
# Iteration: 458; Percent complete: 11.5%; Average loss: 3.6379
# Iteration: 459; Percent complete: 11.5%; Average loss: 3.7437
# Iteration: 460; Percent complete: 11.5%; Average loss: 3.8147
# Iteration: 461; Percent complete: 11.5%; Average loss: 3.7619
# Iteration: 462; Percent complete: 11.6%; Average loss: 3.6080
# Iteration: 463; Percent complete: 11.6%; Average loss: 3.6335
# Iteration: 464; Percent complete: 11.6%; Average loss: 3.8693
# Iteration: 465; Percent complete: 11.6%; Average loss: 3.7864
# Iteration: 466; Percent complete: 11.7%; Average loss: 3.7673
# Iteration: 467; Percent complete: 11.7%; Average loss: 3.4049
# Iteration: 468; Percent complete: 11.7%; Average loss: 3.7392
# Iteration: 469; Percent complete: 11.7%; Average loss: 3.8486
# Iteration: 470; Percent complete: 11.8%; Average loss: 3.8623
# Iteration: 471; Percent complete: 11.8%; Average loss: 3.4429
# Iteration: 472; Percent complete: 11.8%; Average loss: 3.7041
# Iteration: 473; Percent complete: 11.8%; Average loss: 3.7988
# Iteration: 474; Percent complete: 11.8%; Average loss: 3.6120
# Iteration: 475; Percent complete: 11.9%; Average loss: 3.5252
# Iteration: 476; Percent complete: 11.9%; Average loss: 3.8381
# Iteration: 477; Percent complete: 11.9%; Average loss: 3.7143
# Iteration: 478; Percent complete: 11.9%; Average loss: 3.7505
# Iteration: 479; Percent complete: 12.0%; Average loss: 3.8981
# Iteration: 480; Percent complete: 12.0%; Average loss: 3.6379
# Iteration: 481; Percent complete: 12.0%; Average loss: 3.5351
# Iteration: 482; Percent complete: 12.0%; Average loss: 3.9251
# Iteration: 483; Percent complete: 12.1%; Average loss: 3.7349
# Iteration: 484; Percent complete: 12.1%; Average loss: 3.9231
# Iteration: 485; Percent complete: 12.1%; Average loss: 3.7436
# Iteration: 486; Percent complete: 12.2%; Average loss: 3.9469
# Iteration: 487; Percent complete: 12.2%; Average loss: 3.5874
# Iteration: 488; Percent complete: 12.2%; Average loss: 3.9185
# Iteration: 489; Percent complete: 12.2%; Average loss: 3.6026
# Iteration: 490; Percent complete: 12.2%; Average loss: 3.8823
# Iteration: 491; Percent complete: 12.3%; Average loss: 3.6943
# Iteration: 492; Percent complete: 12.3%; Average loss: 3.6442
# Iteration: 493; Percent complete: 12.3%; Average loss: 3.8340
# Iteration: 494; Percent complete: 12.3%; Average loss: 3.6985
# Iteration: 495; Percent complete: 12.4%; Average loss: 4.0053
# Iteration: 496; Percent complete: 12.4%; Average loss: 3.6547
# Iteration: 497; Percent complete: 12.4%; Average loss: 3.6011
# Iteration: 498; Percent complete: 12.4%; Average loss: 3.7727
# Iteration: 499; Percent complete: 12.5%; Average loss: 3.7869
# Iteration: 500; Percent complete: 12.5%; Average loss: 3.6489
# Iteration: 501; Percent complete: 12.5%; Average loss: 3.8353
# Iteration: 502; Percent complete: 12.6%; Average loss: 3.8275
# Iteration: 503; Percent complete: 12.6%; Average loss: 3.6078
# Iteration: 504; Percent complete: 12.6%; Average loss: 3.6928
# Iteration: 505; Percent complete: 12.6%; Average loss: 3.6043
# Iteration: 506; Percent complete: 12.7%; Average loss: 3.6947
# Iteration: 507; Percent complete: 12.7%; Average loss: 3.8728
# Iteration: 508; Percent complete: 12.7%; Average loss: 3.7840
# Iteration: 509; Percent complete: 12.7%; Average loss: 3.6453
# Iteration: 510; Percent complete: 12.8%; Average loss: 3.8375
# Iteration: 511; Percent complete: 12.8%; Average loss: 3.8405
# Iteration: 512; Percent complete: 12.8%; Average loss: 3.6944
# Iteration: 513; Percent complete: 12.8%; Average loss: 3.5260
# Iteration: 514; Percent complete: 12.8%; Average loss: 3.6103
# Iteration: 515; Percent complete: 12.9%; Average loss: 3.6712
# Iteration: 516; Percent complete: 12.9%; Average loss: 3.5858
# Iteration: 517; Percent complete: 12.9%; Average loss: 3.8204
# Iteration: 518; Percent complete: 13.0%; Average loss: 3.7314
# Iteration: 519; Percent complete: 13.0%; Average loss: 3.8018
# Iteration: 520; Percent complete: 13.0%; Average loss: 3.4562
# Iteration: 521; Percent complete: 13.0%; Average loss: 3.7294
# Iteration: 522; Percent complete: 13.1%; Average loss: 3.5395
# Iteration: 523; Percent complete: 13.1%; Average loss: 3.8210
# Iteration: 524; Percent complete: 13.1%; Average loss: 3.6771
# Iteration: 525; Percent complete: 13.1%; Average loss: 3.9631
# Iteration: 526; Percent complete: 13.2%; Average loss: 3.8649
# Iteration: 527; Percent complete: 13.2%; Average loss: 3.6588
# Iteration: 528; Percent complete: 13.2%; Average loss: 3.7774
# Iteration: 529; Percent complete: 13.2%; Average loss: 3.9654
# Iteration: 530; Percent complete: 13.2%; Average loss: 3.6614
# Iteration: 531; Percent complete: 13.3%; Average loss: 3.3566
# Iteration: 532; Percent complete: 13.3%; Average loss: 3.7556
# Iteration: 533; Percent complete: 13.3%; Average loss: 3.3712
# Iteration: 534; Percent complete: 13.4%; Average loss: 3.9848
# Iteration: 535; Percent complete: 13.4%; Average loss: 3.8240
# Iteration: 536; Percent complete: 13.4%; Average loss: 3.5389
# Iteration: 537; Percent complete: 13.4%; Average loss: 3.7723
# Iteration: 538; Percent complete: 13.5%; Average loss: 3.8506
# Iteration: 539; Percent complete: 13.5%; Average loss: 3.4534
# Iteration: 540; Percent complete: 13.5%; Average loss: 3.8799
# Iteration: 541; Percent complete: 13.5%; Average loss: 3.6149
# Iteration: 542; Percent complete: 13.6%; Average loss: 3.6158
# Iteration: 543; Percent complete: 13.6%; Average loss: 3.4190
# Iteration: 544; Percent complete: 13.6%; Average loss: 4.0094
# Iteration: 545; Percent complete: 13.6%; Average loss: 3.4954
# Iteration: 546; Percent complete: 13.7%; Average loss: 3.4103
# Iteration: 547; Percent complete: 13.7%; Average loss: 3.8013
# Iteration: 548; Percent complete: 13.7%; Average loss: 3.8145
# Iteration: 549; Percent complete: 13.7%; Average loss: 3.7464
# Iteration: 550; Percent complete: 13.8%; Average loss: 3.5616
# Iteration: 551; Percent complete: 13.8%; Average loss: 3.6676
# Iteration: 552; Percent complete: 13.8%; Average loss: 3.7756
# Iteration: 553; Percent complete: 13.8%; Average loss: 3.7196
# Iteration: 554; Percent complete: 13.9%; Average loss: 3.5826
# Iteration: 555; Percent complete: 13.9%; Average loss: 3.9628
# Iteration: 556; Percent complete: 13.9%; Average loss: 3.7581
# Iteration: 557; Percent complete: 13.9%; Average loss: 3.5853
# Iteration: 558; Percent complete: 14.0%; Average loss: 3.6632
# Iteration: 559; Percent complete: 14.0%; Average loss: 3.4258
# Iteration: 560; Percent complete: 14.0%; Average loss: 3.5073
# Iteration: 561; Percent complete: 14.0%; Average loss: 3.7396
# Iteration: 562; Percent complete: 14.1%; Average loss: 3.7042
# Iteration: 563; Percent complete: 14.1%; Average loss: 3.7541
# Iteration: 564; Percent complete: 14.1%; Average loss: 3.8397
# Iteration: 565; Percent complete: 14.1%; Average loss: 3.7550
# Iteration: 566; Percent complete: 14.1%; Average loss: 3.7196
# Iteration: 567; Percent complete: 14.2%; Average loss: 3.7436
# Iteration: 568; Percent complete: 14.2%; Average loss: 3.7938
# Iteration: 569; Percent complete: 14.2%; Average loss: 3.9274
# Iteration: 570; Percent complete: 14.2%; Average loss: 4.0902
# Iteration: 571; Percent complete: 14.3%; Average loss: 3.8919
# Iteration: 572; Percent complete: 14.3%; Average loss: 3.9279
# Iteration: 573; Percent complete: 14.3%; Average loss: 3.8391
# Iteration: 574; Percent complete: 14.3%; Average loss: 4.0369
# Iteration: 575; Percent complete: 14.4%; Average loss: 3.5064
# Iteration: 576; Percent complete: 14.4%; Average loss: 3.6425
# Iteration: 577; Percent complete: 14.4%; Average loss: 3.4795
# Iteration: 578; Percent complete: 14.4%; Average loss: 3.8049
# Iteration: 579; Percent complete: 14.5%; Average loss: 3.6594
# Iteration: 580; Percent complete: 14.5%; Average loss: 3.7301
# Iteration: 581; Percent complete: 14.5%; Average loss: 3.6991
# Iteration: 582; Percent complete: 14.5%; Average loss: 3.5703
# Iteration: 583; Percent complete: 14.6%; Average loss: 3.6464
# Iteration: 584; Percent complete: 14.6%; Average loss: 3.5378
# Iteration: 585; Percent complete: 14.6%; Average loss: 3.8069
# Iteration: 586; Percent complete: 14.6%; Average loss: 3.5876
# Iteration: 587; Percent complete: 14.7%; Average loss: 3.5631
# Iteration: 588; Percent complete: 14.7%; Average loss: 3.4567
# Iteration: 589; Percent complete: 14.7%; Average loss: 3.6647
# Iteration: 590; Percent complete: 14.8%; Average loss: 3.8441
# Iteration: 591; Percent complete: 14.8%; Average loss: 3.6641
# Iteration: 592; Percent complete: 14.8%; Average loss: 3.6330
# Iteration: 593; Percent complete: 14.8%; Average loss: 3.5985
# Iteration: 594; Percent complete: 14.8%; Average loss: 3.3629
# Iteration: 595; Percent complete: 14.9%; Average loss: 3.3540
# Iteration: 596; Percent complete: 14.9%; Average loss: 3.5315
# Iteration: 597; Percent complete: 14.9%; Average loss: 3.5794
# Iteration: 598; Percent complete: 14.9%; Average loss: 3.5333
# Iteration: 599; Percent complete: 15.0%; Average loss: 3.6522
# Iteration: 600; Percent complete: 15.0%; Average loss: 3.5374
# Iteration: 601; Percent complete: 15.0%; Average loss: 3.6614
# Iteration: 602; Percent complete: 15.0%; Average loss: 3.6116
# Iteration: 603; Percent complete: 15.1%; Average loss: 3.7440
# Iteration: 604; Percent complete: 15.1%; Average loss: 3.8968
# Iteration: 605; Percent complete: 15.1%; Average loss: 3.6113
# Iteration: 606; Percent complete: 15.2%; Average loss: 3.6544
# Iteration: 607; Percent complete: 15.2%; Average loss: 3.6055
# Iteration: 608; Percent complete: 15.2%; Average loss: 3.6389
# Iteration: 609; Percent complete: 15.2%; Average loss: 3.8207
# Iteration: 610; Percent complete: 15.2%; Average loss: 3.6221
# Iteration: 611; Percent complete: 15.3%; Average loss: 3.7045
# Iteration: 612; Percent complete: 15.3%; Average loss: 3.7782
# Iteration: 613; Percent complete: 15.3%; Average loss: 3.4337
# Iteration: 614; Percent complete: 15.3%; Average loss: 3.5824
# Iteration: 615; Percent complete: 15.4%; Average loss: 4.0125
# Iteration: 616; Percent complete: 15.4%; Average loss: 3.6873
# Iteration: 617; Percent complete: 15.4%; Average loss: 3.5884
# Iteration: 618; Percent complete: 15.4%; Average loss: 3.7436
# Iteration: 619; Percent complete: 15.5%; Average loss: 3.7044
# Iteration: 620; Percent complete: 15.5%; Average loss: 3.5912
# Iteration: 621; Percent complete: 15.5%; Average loss: 3.7505
# Iteration: 622; Percent complete: 15.6%; Average loss: 3.7747
# Iteration: 623; Percent complete: 15.6%; Average loss: 3.4402
# Iteration: 624; Percent complete: 15.6%; Average loss: 3.6525
# Iteration: 625; Percent complete: 15.6%; Average loss: 3.4421
# Iteration: 626; Percent complete: 15.7%; Average loss: 3.9048
# Iteration: 627; Percent complete: 15.7%; Average loss: 3.5888
# Iteration: 628; Percent complete: 15.7%; Average loss: 3.5616
# Iteration: 629; Percent complete: 15.7%; Average loss: 3.9161
# Iteration: 630; Percent complete: 15.8%; Average loss: 3.5737
# Iteration: 631; Percent complete: 15.8%; Average loss: 3.4290
# Iteration: 632; Percent complete: 15.8%; Average loss: 3.4590
# Iteration: 633; Percent complete: 15.8%; Average loss: 3.6349
# Iteration: 634; Percent complete: 15.8%; Average loss: 3.5519
# Iteration: 635; Percent complete: 15.9%; Average loss: 3.5382
# Iteration: 636; Percent complete: 15.9%; Average loss: 3.5912
# Iteration: 637; Percent complete: 15.9%; Average loss: 3.5993
# Iteration: 638; Percent complete: 16.0%; Average loss: 3.5267
# Iteration: 639; Percent complete: 16.0%; Average loss: 3.6986
# Iteration: 640; Percent complete: 16.0%; Average loss: 3.4421
# Iteration: 641; Percent complete: 16.0%; Average loss: 3.3872
# Iteration: 642; Percent complete: 16.1%; Average loss: 3.6045
# Iteration: 643; Percent complete: 16.1%; Average loss: 3.5751
# Iteration: 644; Percent complete: 16.1%; Average loss: 3.6629
# Iteration: 645; Percent complete: 16.1%; Average loss: 3.4371
# Iteration: 646; Percent complete: 16.2%; Average loss: 3.8187
# Iteration: 647; Percent complete: 16.2%; Average loss: 3.6545
# Iteration: 648; Percent complete: 16.2%; Average loss: 3.4888
# Iteration: 649; Percent complete: 16.2%; Average loss: 3.5183
# Iteration: 650; Percent complete: 16.2%; Average loss: 3.6286
# Iteration: 651; Percent complete: 16.3%; Average loss: 3.7231
# Iteration: 652; Percent complete: 16.3%; Average loss: 3.7569
# Iteration: 653; Percent complete: 16.3%; Average loss: 3.5936
# Iteration: 654; Percent complete: 16.4%; Average loss: 3.6586
# Iteration: 655; Percent complete: 16.4%; Average loss: 3.6718
# Iteration: 656; Percent complete: 16.4%; Average loss: 3.5875
# Iteration: 657; Percent complete: 16.4%; Average loss: 3.4942
# Iteration: 658; Percent complete: 16.4%; Average loss: 3.5761
# Iteration: 659; Percent complete: 16.5%; Average loss: 3.6603
# Iteration: 660; Percent complete: 16.5%; Average loss: 3.5165
# Iteration: 661; Percent complete: 16.5%; Average loss: 3.6447
# Iteration: 662; Percent complete: 16.6%; Average loss: 3.6458
# Iteration: 663; Percent complete: 16.6%; Average loss: 3.5182
# Iteration: 664; Percent complete: 16.6%; Average loss: 3.6258
# Iteration: 665; Percent complete: 16.6%; Average loss: 3.5193
# Iteration: 666; Percent complete: 16.7%; Average loss: 3.4948
# Iteration: 667; Percent complete: 16.7%; Average loss: 3.4687
# Iteration: 668; Percent complete: 16.7%; Average loss: 3.6005
# Iteration: 669; Percent complete: 16.7%; Average loss: 3.4084
# Iteration: 670; Percent complete: 16.8%; Average loss: 3.6959
# Iteration: 671; Percent complete: 16.8%; Average loss: 3.6643
# Iteration: 672; Percent complete: 16.8%; Average loss: 3.7253
# Iteration: 673; Percent complete: 16.8%; Average loss: 3.5632
# Iteration: 674; Percent complete: 16.9%; Average loss: 3.7759
# Iteration: 675; Percent complete: 16.9%; Average loss: 3.4275
# Iteration: 676; Percent complete: 16.9%; Average loss: 3.7929
# Iteration: 677; Percent complete: 16.9%; Average loss: 3.7212
# Iteration: 678; Percent complete: 17.0%; Average loss: 3.6936
# Iteration: 679; Percent complete: 17.0%; Average loss: 3.7186
# Iteration: 680; Percent complete: 17.0%; Average loss: 3.7429
# Iteration: 681; Percent complete: 17.0%; Average loss: 3.5021
# Iteration: 682; Percent complete: 17.1%; Average loss: 3.7065
# Iteration: 683; Percent complete: 17.1%; Average loss: 3.6676
# Iteration: 684; Percent complete: 17.1%; Average loss: 3.9779
# Iteration: 685; Percent complete: 17.1%; Average loss: 3.7421
# Iteration: 686; Percent complete: 17.2%; Average loss: 3.7726
# Iteration: 687; Percent complete: 17.2%; Average loss: 3.5547
# Iteration: 688; Percent complete: 17.2%; Average loss: 3.7216
# Iteration: 689; Percent complete: 17.2%; Average loss: 3.6943
# Iteration: 690; Percent complete: 17.2%; Average loss: 3.6475
# Iteration: 691; Percent complete: 17.3%; Average loss: 3.6739
# Iteration: 692; Percent complete: 17.3%; Average loss: 3.5959
# Iteration: 693; Percent complete: 17.3%; Average loss: 3.7988
# Iteration: 694; Percent complete: 17.3%; Average loss: 3.5658
# Iteration: 695; Percent complete: 17.4%; Average loss: 3.6263
# Iteration: 696; Percent complete: 17.4%; Average loss: 3.5555
# Iteration: 697; Percent complete: 17.4%; Average loss: 3.3852
# Iteration: 698; Percent complete: 17.4%; Average loss: 3.5001
# Iteration: 699; Percent complete: 17.5%; Average loss: 3.6811
# Iteration: 700; Percent complete: 17.5%; Average loss: 3.1940
# Iteration: 701; Percent complete: 17.5%; Average loss: 3.4711
# Iteration: 702; Percent complete: 17.5%; Average loss: 3.4860
# Iteration: 703; Percent complete: 17.6%; Average loss: 3.8512
# Iteration: 704; Percent complete: 17.6%; Average loss: 3.5105
# Iteration: 705; Percent complete: 17.6%; Average loss: 3.3566
# Iteration: 706; Percent complete: 17.6%; Average loss: 3.5280
# Iteration: 707; Percent complete: 17.7%; Average loss: 3.7028
# Iteration: 708; Percent complete: 17.7%; Average loss: 3.5410
# Iteration: 709; Percent complete: 17.7%; Average loss: 3.6374
# Iteration: 710; Percent complete: 17.8%; Average loss: 3.4284
# Iteration: 711; Percent complete: 17.8%; Average loss: 3.7385
# Iteration: 712; Percent complete: 17.8%; Average loss: 3.5088
# Iteration: 713; Percent complete: 17.8%; Average loss: 3.5615
# Iteration: 714; Percent complete: 17.8%; Average loss: 3.5300
# Iteration: 715; Percent complete: 17.9%; Average loss: 3.7154
# Iteration: 716; Percent complete: 17.9%; Average loss: 3.4851
# Iteration: 717; Percent complete: 17.9%; Average loss: 3.7662
# Iteration: 718; Percent complete: 17.9%; Average loss: 3.3604
# Iteration: 719; Percent complete: 18.0%; Average loss: 3.5043
# Iteration: 720; Percent complete: 18.0%; Average loss: 3.3669
# Iteration: 721; Percent complete: 18.0%; Average loss: 3.7709
# Iteration: 722; Percent complete: 18.1%; Average loss: 3.7937
# Iteration: 723; Percent complete: 18.1%; Average loss: 3.6482
# Iteration: 724; Percent complete: 18.1%; Average loss: 3.7625
# Iteration: 725; Percent complete: 18.1%; Average loss: 3.4948
# Iteration: 726; Percent complete: 18.1%; Average loss: 3.8164
# Iteration: 727; Percent complete: 18.2%; Average loss: 3.7530
# Iteration: 728; Percent complete: 18.2%; Average loss: 3.4791
# Iteration: 729; Percent complete: 18.2%; Average loss: 3.7527
# Iteration: 730; Percent complete: 18.2%; Average loss: 3.5159
# Iteration: 731; Percent complete: 18.3%; Average loss: 3.3677
# Iteration: 732; Percent complete: 18.3%; Average loss: 3.4331
# Iteration: 733; Percent complete: 18.3%; Average loss: 3.7329
# Iteration: 734; Percent complete: 18.4%; Average loss: 3.4396
# Iteration: 735; Percent complete: 18.4%; Average loss: 3.4927
# Iteration: 736; Percent complete: 18.4%; Average loss: 3.5976
# Iteration: 737; Percent complete: 18.4%; Average loss: 3.4870
# Iteration: 738; Percent complete: 18.4%; Average loss: 3.6360
# Iteration: 739; Percent complete: 18.5%; Average loss: 3.5589
# Iteration: 740; Percent complete: 18.5%; Average loss: 3.5495
# Iteration: 741; Percent complete: 18.5%; Average loss: 3.6774
# Iteration: 742; Percent complete: 18.6%; Average loss: 3.4060
# Iteration: 743; Percent complete: 18.6%; Average loss: 3.6404
# Iteration: 744; Percent complete: 18.6%; Average loss: 3.5944
# Iteration: 745; Percent complete: 18.6%; Average loss: 3.5342
# Iteration: 746; Percent complete: 18.6%; Average loss: 3.7267
# Iteration: 747; Percent complete: 18.7%; Average loss: 3.9582
# Iteration: 748; Percent complete: 18.7%; Average loss: 3.4510
# Iteration: 749; Percent complete: 18.7%; Average loss: 3.4521
# Iteration: 750; Percent complete: 18.8%; Average loss: 3.5132
# Iteration: 751; Percent complete: 18.8%; Average loss: 3.8443
# Iteration: 752; Percent complete: 18.8%; Average loss: 3.7418
# Iteration: 753; Percent complete: 18.8%; Average loss: 3.5604
# Iteration: 754; Percent complete: 18.9%; Average loss: 3.6738
# Iteration: 755; Percent complete: 18.9%; Average loss: 3.5836
# Iteration: 756; Percent complete: 18.9%; Average loss: 3.7291
# Iteration: 757; Percent complete: 18.9%; Average loss: 3.4849
# Iteration: 758; Percent complete: 18.9%; Average loss: 3.4583
# Iteration: 759; Percent complete: 19.0%; Average loss: 3.4303
# Iteration: 760; Percent complete: 19.0%; Average loss: 3.3346
# Iteration: 761; Percent complete: 19.0%; Average loss: 3.5355
# Iteration: 762; Percent complete: 19.1%; Average loss: 3.4686
# Iteration: 763; Percent complete: 19.1%; Average loss: 3.4265
# Iteration: 764; Percent complete: 19.1%; Average loss: 3.3797
# Iteration: 765; Percent complete: 19.1%; Average loss: 3.5427
# Iteration: 766; Percent complete: 19.1%; Average loss: 3.5861
# Iteration: 767; Percent complete: 19.2%; Average loss: 3.7725
# Iteration: 768; Percent complete: 19.2%; Average loss: 3.4067
# Iteration: 769; Percent complete: 19.2%; Average loss: 3.6644
# Iteration: 770; Percent complete: 19.2%; Average loss: 3.6304
# Iteration: 771; Percent complete: 19.3%; Average loss: 3.7625
# Iteration: 772; Percent complete: 19.3%; Average loss: 3.5535
# Iteration: 773; Percent complete: 19.3%; Average loss: 3.5282
# Iteration: 774; Percent complete: 19.4%; Average loss: 3.4391
# Iteration: 775; Percent complete: 19.4%; Average loss: 3.5646
# Iteration: 776; Percent complete: 19.4%; Average loss: 3.7143
# Iteration: 777; Percent complete: 19.4%; Average loss: 3.4555
# Iteration: 778; Percent complete: 19.4%; Average loss: 3.4021
# Iteration: 779; Percent complete: 19.5%; Average loss: 3.7472
# Iteration: 780; Percent complete: 19.5%; Average loss: 3.7076
# Iteration: 781; Percent complete: 19.5%; Average loss: 3.7915
# ...
# Iteration: 3748; Percent complete: 93.7%; Average loss: 2.4142
# Iteration: 3749; Percent complete: 93.7%; Average loss: 2.7424
# Iteration: 3750; Percent complete: 93.8%; Average loss: 2.6799
# Iteration: 3751; Percent complete: 93.8%; Average loss: 2.6510
# Iteration: 3752; Percent complete: 93.8%; Average loss: 2.8303
# Iteration: 3753; Percent complete: 93.8%; Average loss: 2.8662
# Iteration: 3754; Percent complete: 93.8%; Average loss: 2.5312
# Iteration: 3755; Percent complete: 93.9%; Average loss: 2.8399
# Iteration: 3756; Percent complete: 93.9%; Average loss: 2.6644
# Iteration: 3757; Percent complete: 93.9%; Average loss: 2.7564
# Iteration: 3758; Percent complete: 94.0%; Average loss: 2.7081
# Iteration: 3759; Percent complete: 94.0%; Average loss: 2.6494
# Iteration: 3760; Percent complete: 94.0%; Average loss: 2.6022
# Iteration: 3761; Percent complete: 94.0%; Average loss: 2.4560
# Iteration: 3762; Percent complete: 94.0%; Average loss: 2.5814
# Iteration: 3763; Percent complete: 94.1%; Average loss: 2.4744
# Iteration: 3764; Percent complete: 94.1%; Average loss: 2.6672
# Iteration: 3765; Percent complete: 94.1%; Average loss: 2.6666
# Iteration: 3766; Percent complete: 94.2%; Average loss: 2.7401
# Iteration: 3767; Percent complete: 94.2%; Average loss: 2.6988
# Iteration: 3768; Percent complete: 94.2%; Average loss: 2.7138
# Iteration: 3769; Percent complete: 94.2%; Average loss: 2.6661
# Iteration: 3770; Percent complete: 94.2%; Average loss: 2.5405
# Iteration: 3771; Percent complete: 94.3%; Average loss: 2.6359
# Iteration: 3772; Percent complete: 94.3%; Average loss: 2.9103
# Iteration: 3773; Percent complete: 94.3%; Average loss: 2.8447
# Iteration: 3774; Percent complete: 94.3%; Average loss: 2.7538
# Iteration: 3775; Percent complete: 94.4%; Average loss: 2.6785
# Iteration: 3776; Percent complete: 94.4%; Average loss: 2.7659
# Iteration: 3777; Percent complete: 94.4%; Average loss: 2.5439
# Iteration: 3778; Percent complete: 94.5%; Average loss: 2.6409
# Iteration: 3779; Percent complete: 94.5%; Average loss: 2.7091
# Iteration: 3780; Percent complete: 94.5%; Average loss: 2.5562
# Iteration: 3781; Percent complete: 94.5%; Average loss: 2.6413
# Iteration: 3782; Percent complete: 94.5%; Average loss: 2.5726
# Iteration: 3783; Percent complete: 94.6%; Average loss: 2.4629
# Iteration: 3784; Percent complete: 94.6%; Average loss: 2.7011
# Iteration: 3785; Percent complete: 94.6%; Average loss: 2.6526
# Iteration: 3786; Percent complete: 94.7%; Average loss: 2.7625
# Iteration: 3787; Percent complete: 94.7%; Average loss: 2.8478
# Iteration: 3788; Percent complete: 94.7%; Average loss: 2.8271
# Iteration: 3789; Percent complete: 94.7%; Average loss: 2.5953
# Iteration: 3790; Percent complete: 94.8%; Average loss: 2.6456
# Iteration: 3791; Percent complete: 94.8%; Average loss: 2.7488
# Iteration: 3792; Percent complete: 94.8%; Average loss: 2.5570
# Iteration: 3793; Percent complete: 94.8%; Average loss: 2.3579
# Iteration: 3794; Percent complete: 94.8%; Average loss: 2.6669
# Iteration: 3795; Percent complete: 94.9%; Average loss: 2.6328
# Iteration: 3796; Percent complete: 94.9%; Average loss: 2.5764
# Iteration: 3797; Percent complete: 94.9%; Average loss: 2.8873
# Iteration: 3798; Percent complete: 95.0%; Average loss: 2.6828
# Iteration: 3799; Percent complete: 95.0%; Average loss: 2.7404
# Iteration: 3800; Percent complete: 95.0%; Average loss: 2.9185
# Iteration: 3801; Percent complete: 95.0%; Average loss: 2.6002
# Iteration: 3802; Percent complete: 95.0%; Average loss: 2.5291
# Iteration: 3803; Percent complete: 95.1%; Average loss: 2.7599
# Iteration: 3804; Percent complete: 95.1%; Average loss: 2.5201
# Iteration: 3805; Percent complete: 95.1%; Average loss: 2.5990
# Iteration: 3806; Percent complete: 95.2%; Average loss: 2.5613
# Iteration: 3807; Percent complete: 95.2%; Average loss: 2.6767
# Iteration: 3808; Percent complete: 95.2%; Average loss: 2.5628
# Iteration: 3809; Percent complete: 95.2%; Average loss: 2.6628
# Iteration: 3810; Percent complete: 95.2%; Average loss: 2.4889
# Iteration: 3811; Percent complete: 95.3%; Average loss: 2.5496
# Iteration: 3812; Percent complete: 95.3%; Average loss: 2.6498
# Iteration: 3813; Percent complete: 95.3%; Average loss: 2.8590
# Iteration: 3814; Percent complete: 95.3%; Average loss: 2.4308
# Iteration: 3815; Percent complete: 95.4%; Average loss: 2.6533
# Iteration: 3816; Percent complete: 95.4%; Average loss: 2.5695
# Iteration: 3817; Percent complete: 95.4%; Average loss: 2.6493
# Iteration: 3818; Percent complete: 95.5%; Average loss: 2.5615
# Iteration: 3819; Percent complete: 95.5%; Average loss: 2.6631
# Iteration: 3820; Percent complete: 95.5%; Average loss: 2.8752
# Iteration: 3821; Percent complete: 95.5%; Average loss: 2.6400
# Iteration: 3822; Percent complete: 95.5%; Average loss: 2.6113
# Iteration: 3823; Percent complete: 95.6%; Average loss: 2.6180
# Iteration: 3824; Percent complete: 95.6%; Average loss: 2.5592
# Iteration: 3825; Percent complete: 95.6%; Average loss: 2.7734
# Iteration: 3826; Percent complete: 95.7%; Average loss: 2.5687
# Iteration: 3827; Percent complete: 95.7%; Average loss: 2.4364
# Iteration: 3828; Percent complete: 95.7%; Average loss: 2.5221
# Iteration: 3829; Percent complete: 95.7%; Average loss: 2.7110
# Iteration: 3830; Percent complete: 95.8%; Average loss: 2.5706
# Iteration: 3831; Percent complete: 95.8%; Average loss: 2.6111
# Iteration: 3832; Percent complete: 95.8%; Average loss: 2.7758
# Iteration: 3833; Percent complete: 95.8%; Average loss: 2.5490
# Iteration: 3834; Percent complete: 95.9%; Average loss: 2.4240
# Iteration: 3835; Percent complete: 95.9%; Average loss: 2.8926
# Iteration: 3836; Percent complete: 95.9%; Average loss: 2.4290
# Iteration: 3837; Percent complete: 95.9%; Average loss: 2.4947
# Iteration: 3838; Percent complete: 96.0%; Average loss: 2.7025
# Iteration: 3839; Percent complete: 96.0%; Average loss: 2.6575
# Iteration: 3840; Percent complete: 96.0%; Average loss: 2.6337
# Iteration: 3841; Percent complete: 96.0%; Average loss: 2.6762
# Iteration: 3842; Percent complete: 96.0%; Average loss: 2.7200
# Iteration: 3843; Percent complete: 96.1%; Average loss: 2.7710
# Iteration: 3844; Percent complete: 96.1%; Average loss: 2.7605
# Iteration: 3845; Percent complete: 96.1%; Average loss: 2.7453
# Iteration: 3846; Percent complete: 96.2%; Average loss: 2.6133
# Iteration: 3847; Percent complete: 96.2%; Average loss: 2.6041
# Iteration: 3848; Percent complete: 96.2%; Average loss: 2.5897
# Iteration: 3849; Percent complete: 96.2%; Average loss: 2.7111
# Iteration: 3850; Percent complete: 96.2%; Average loss: 2.6113
# Iteration: 3851; Percent complete: 96.3%; Average loss: 2.6086
# Iteration: 3852; Percent complete: 96.3%; Average loss: 2.5321
# Iteration: 3853; Percent complete: 96.3%; Average loss: 2.6642
# Iteration: 3854; Percent complete: 96.4%; Average loss: 2.7196
# Iteration: 3855; Percent complete: 96.4%; Average loss: 2.6075
# Iteration: 3856; Percent complete: 96.4%; Average loss: 2.6092
# Iteration: 3857; Percent complete: 96.4%; Average loss: 2.7669
# Iteration: 3858; Percent complete: 96.5%; Average loss: 2.7717
# Iteration: 3859; Percent complete: 96.5%; Average loss: 2.5647
# Iteration: 3860; Percent complete: 96.5%; Average loss: 2.5980
# Iteration: 3861; Percent complete: 96.5%; Average loss: 2.7724
# Iteration: 3862; Percent complete: 96.5%; Average loss: 2.7124
# Iteration: 3863; Percent complete: 96.6%; Average loss: 2.4808
# Iteration: 3864; Percent complete: 96.6%; Average loss: 2.6127
# Iteration: 3865; Percent complete: 96.6%; Average loss: 2.5603
# Iteration: 3866; Percent complete: 96.7%; Average loss: 2.6838
# Iteration: 3867; Percent complete: 96.7%; Average loss: 2.8725
# Iteration: 3868; Percent complete: 96.7%; Average loss: 2.5670
# Iteration: 3869; Percent complete: 96.7%; Average loss: 2.9783
# Iteration: 3870; Percent complete: 96.8%; Average loss: 2.6106
# Iteration: 3871; Percent complete: 96.8%; Average loss: 2.6376
# Iteration: 3872; Percent complete: 96.8%; Average loss: 2.5277
# Iteration: 3873; Percent complete: 96.8%; Average loss: 2.5718
# Iteration: 3874; Percent complete: 96.9%; Average loss: 2.4814
# Iteration: 3875; Percent complete: 96.9%; Average loss: 2.7302
# Iteration: 3876; Percent complete: 96.9%; Average loss: 2.8273
# Iteration: 3877; Percent complete: 96.9%; Average loss: 2.5623
# Iteration: 3878; Percent complete: 97.0%; Average loss: 2.7600
# Iteration: 3879; Percent complete: 97.0%; Average loss: 2.4189
# Iteration: 3880; Percent complete: 97.0%; Average loss: 2.7709
# Iteration: 3881; Percent complete: 97.0%; Average loss: 2.7565
# Iteration: 3882; Percent complete: 97.0%; Average loss: 2.6747
# Iteration: 3883; Percent complete: 97.1%; Average loss: 2.5567
# Iteration: 3884; Percent complete: 97.1%; Average loss: 2.6846
# Iteration: 3885; Percent complete: 97.1%; Average loss: 2.5615
# Iteration: 3886; Percent complete: 97.2%; Average loss: 2.4868
# Iteration: 3887; Percent complete: 97.2%; Average loss: 2.6981
# Iteration: 3888; Percent complete: 97.2%; Average loss: 2.5544
# Iteration: 3889; Percent complete: 97.2%; Average loss: 2.7312
# Iteration: 3890; Percent complete: 97.2%; Average loss: 2.7536
# Iteration: 3891; Percent complete: 97.3%; Average loss: 2.7424
# Iteration: 3892; Percent complete: 97.3%; Average loss: 2.6863
# Iteration: 3893; Percent complete: 97.3%; Average loss: 2.6285
# Iteration: 3894; Percent complete: 97.4%; Average loss: 2.5896
# Iteration: 3895; Percent complete: 97.4%; Average loss: 2.4428
# Iteration: 3896; Percent complete: 97.4%; Average loss: 2.7612
# Iteration: 3897; Percent complete: 97.4%; Average loss: 2.8430
# Iteration: 3898; Percent complete: 97.5%; Average loss: 2.4888
# Iteration: 3899; Percent complete: 97.5%; Average loss: 2.5333
# Iteration: 3900; Percent complete: 97.5%; Average loss: 2.7170
# Iteration: 3901; Percent complete: 97.5%; Average loss: 2.7782
# Iteration: 3902; Percent complete: 97.5%; Average loss: 2.6225
# Iteration: 3903; Percent complete: 97.6%; Average loss: 2.8921
# Iteration: 3904; Percent complete: 97.6%; Average loss: 2.5669
# Iteration: 3905; Percent complete: 97.6%; Average loss: 2.6372
# Iteration: 3906; Percent complete: 97.7%; Average loss: 2.6289
# Iteration: 3907; Percent complete: 97.7%; Average loss: 2.6381
# Iteration: 3908; Percent complete: 97.7%; Average loss: 2.8376
# Iteration: 3909; Percent complete: 97.7%; Average loss: 2.5989
# Iteration: 3910; Percent complete: 97.8%; Average loss: 2.7369
# Iteration: 3911; Percent complete: 97.8%; Average loss: 2.4766
# Iteration: 3912; Percent complete: 97.8%; Average loss: 2.8154
# Iteration: 3913; Percent complete: 97.8%; Average loss: 2.7721
# Iteration: 3914; Percent complete: 97.9%; Average loss: 2.7860
# Iteration: 3915; Percent complete: 97.9%; Average loss: 2.7619
# Iteration: 3916; Percent complete: 97.9%; Average loss: 2.5777
# Iteration: 3917; Percent complete: 97.9%; Average loss: 2.8688
# Iteration: 3918; Percent complete: 98.0%; Average loss: 2.4280
# Iteration: 3919; Percent complete: 98.0%; Average loss: 2.6177
# Iteration: 3920; Percent complete: 98.0%; Average loss: 2.6522
# Iteration: 3921; Percent complete: 98.0%; Average loss: 2.6228
# Iteration: 3922; Percent complete: 98.0%; Average loss: 2.5842
# Iteration: 3923; Percent complete: 98.1%; Average loss: 2.6262
# Iteration: 3924; Percent complete: 98.1%; Average loss: 2.5363
# Iteration: 3925; Percent complete: 98.1%; Average loss: 2.8158
# Iteration: 3926; Percent complete: 98.2%; Average loss: 2.2832
# Iteration: 3927; Percent complete: 98.2%; Average loss: 2.6153
# Iteration: 3928; Percent complete: 98.2%; Average loss: 2.4141
# Iteration: 3929; Percent complete: 98.2%; Average loss: 2.4835
# Iteration: 3930; Percent complete: 98.2%; Average loss: 2.8598
# Iteration: 3931; Percent complete: 98.3%; Average loss: 2.5516
# Iteration: 3932; Percent complete: 98.3%; Average loss: 2.5573
# Iteration: 3933; Percent complete: 98.3%; Average loss: 2.6283
# Iteration: 3934; Percent complete: 98.4%; Average loss: 2.6095
# Iteration: 3935; Percent complete: 98.4%; Average loss: 2.6283
# Iteration: 3936; Percent complete: 98.4%; Average loss: 2.6634
# Iteration: 3937; Percent complete: 98.4%; Average loss: 2.5826
# Iteration: 3938; Percent complete: 98.5%; Average loss: 2.5122
# Iteration: 3939; Percent complete: 98.5%; Average loss: 2.5660
# Iteration: 3940; Percent complete: 98.5%; Average loss: 2.6291
# Iteration: 3941; Percent complete: 98.5%; Average loss: 2.5150
# Iteration: 3942; Percent complete: 98.6%; Average loss: 2.9622
# Iteration: 3943; Percent complete: 98.6%; Average loss: 2.4425
# Iteration: 3944; Percent complete: 98.6%; Average loss: 2.6295
# Iteration: 3945; Percent complete: 98.6%; Average loss: 2.7138
# Iteration: 3946; Percent complete: 98.7%; Average loss: 2.6265
# Iteration: 3947; Percent complete: 98.7%; Average loss: 2.6838
# Iteration: 3948; Percent complete: 98.7%; Average loss: 2.5472
# Iteration: 3949; Percent complete: 98.7%; Average loss: 2.6272
# Iteration: 3950; Percent complete: 98.8%; Average loss: 2.6453
# Iteration: 3951; Percent complete: 98.8%; Average loss: 2.3892
# Iteration: 3952; Percent complete: 98.8%; Average loss: 2.3651
# Iteration: 3953; Percent complete: 98.8%; Average loss: 2.7995
# Iteration: 3954; Percent complete: 98.9%; Average loss: 2.3552
# Iteration: 3955; Percent complete: 98.9%; Average loss: 2.7794
# Iteration: 3956; Percent complete: 98.9%; Average loss: 2.3159
# Iteration: 3957; Percent complete: 98.9%; Average loss: 2.6496
# Iteration: 3958; Percent complete: 99.0%; Average loss: 2.6287
# Iteration: 3959; Percent complete: 99.0%; Average loss: 2.5078
# Iteration: 3960; Percent complete: 99.0%; Average loss: 2.7835
# Iteration: 3961; Percent complete: 99.0%; Average loss: 2.7524
# Iteration: 3962; Percent complete: 99.1%; Average loss: 2.7976
# Iteration: 3963; Percent complete: 99.1%; Average loss: 2.6888
# Iteration: 3964; Percent complete: 99.1%; Average loss: 2.6050
# Iteration: 3965; Percent complete: 99.1%; Average loss: 2.5796
# Iteration: 3966; Percent complete: 99.2%; Average loss: 2.6487
# Iteration: 3967; Percent complete: 99.2%; Average loss: 2.4984
# Iteration: 3968; Percent complete: 99.2%; Average loss: 2.6931
# Iteration: 3969; Percent complete: 99.2%; Average loss: 2.5275
# Iteration: 3970; Percent complete: 99.2%; Average loss: 2.4122
# Iteration: 3971; Percent complete: 99.3%; Average loss: 2.7410
# Iteration: 3972; Percent complete: 99.3%; Average loss: 2.5842
# Iteration: 3973; Percent complete: 99.3%; Average loss: 2.6124
# Iteration: 3974; Percent complete: 99.4%; Average loss: 2.6609
# Iteration: 3975; Percent complete: 99.4%; Average loss: 2.6060
# Iteration: 3976; Percent complete: 99.4%; Average loss: 2.8545
# Iteration: 3977; Percent complete: 99.4%; Average loss: 2.4468
# Iteration: 3978; Percent complete: 99.5%; Average loss: 2.9037
# Iteration: 3979; Percent complete: 99.5%; Average loss: 2.4859
# Iteration: 3980; Percent complete: 99.5%; Average loss: 2.4727
# Iteration: 3981; Percent complete: 99.5%; Average loss: 2.8072
# Iteration: 3982; Percent complete: 99.6%; Average loss: 2.7041
# Iteration: 3983; Percent complete: 99.6%; Average loss: 2.6097
# Iteration: 3984; Percent complete: 99.6%; Average loss: 2.6508
# Iteration: 3985; Percent complete: 99.6%; Average loss: 2.6466
# Iteration: 3986; Percent complete: 99.7%; Average loss: 2.9120
# Iteration: 3987; Percent complete: 99.7%; Average loss: 2.3815
# Iteration: 3988; Percent complete: 99.7%; Average loss: 2.3478
# Iteration: 3989; Percent complete: 99.7%; Average loss: 2.6146
# Iteration: 3990; Percent complete: 99.8%; Average loss: 2.7322
# Iteration: 3991; Percent complete: 99.8%; Average loss: 2.6957
# Iteration: 3992; Percent complete: 99.8%; Average loss: 2.6070
# Iteration: 3993; Percent complete: 99.8%; Average loss: 2.7351
# Iteration: 3994; Percent complete: 99.9%; Average loss: 2.5029
# Iteration: 3995; Percent complete: 99.9%; Average loss: 2.4579
# Iteration: 3996; Percent complete: 99.9%; Average loss: 2.6390
# Iteration: 3997; Percent complete: 99.9%; Average loss: 2.5711
# Iteration: 3998; Percent complete: 100.0%; Average loss: 2.5042
# Iteration: 3999; Percent complete: 100.0%; Average loss: 2.5132
# Iteration: 4000; Percent complete: 100.0%; Average loss: 2.4864
# 3.2314426802895784

# %% [markdown]
# ### Run Evaluation
#
# To chat with your model, run the following block.

# %%
# Set dropout layers to eval mode
encoder.eval()
decoder.eval()

# Initialize search module
searcher = GreedySearchDecoder(encoder, decoder)

# Begin chatting (uncomment and run the following line to begin)
evaluateInput(encoder, decoder, searcher, voc)
# Out:
# > hi
# Bot: hi . s late . .
# > quit

# %% [markdown]
# ## Conclusion
#
# That’s all for this one, folks. Congratulations, you now know the
# fundamentals to building a generative chatbot model! If you’re
# interested, you can try tailoring the chatbot’s behavior by tweaking the
# model and training parameters and customizing the data that you train
# the model on.
#
# Check out the other tutorials for more cool deep learning applications
# in PyTorch!

# %% [markdown]
# ***Q.3, Q.4***

# %%
# !pip install wandb -qU

# %%
import wandb

# %%
# Log in to your W&B account

wandb.login()
# Out:
# wandb: Currently logged in as: rs8385 (rithviik). Use `wandb login --relogin` to force relogin
# True

# %%
sweep_config = {
    "name": "hyperparameter_sweep",
    'metric': {'goal': 'minimize', 'name': 'loss'},
    "method": "random",
    "parameters": {
  
        "learning_rate": {
            "values": [0.0001, 0.00025, 0.0005, 0.001]
        },
        "optimizer": {
            "values": ["adam", "sgd"]
        },
        "clip": {
            "values": [0, 25, 50, 100]
        },
        "teacher_forcing_ratio": {
            "values": [0, 0.5, 1.0]
        },
        "decoder_learning_ratio": {
            "values": [1.0, 3.0, 5.0, 10.0]
        }
    }
}
# Configure models
model_name = 'cb_model_wandb'
attn_model = 'dot'
hidden_size = 500
encoder_n_layers = 2
decoder_n_layers = 2
dropout = 0.1
batch_size = 64


def wandb_train():  
    # Initialize a new WandB run
    wandb.init()


    # Set the hyperparameters for this run
    config = wandb.config
    config.learning_rate = sweep_config['parameters']['learning_rate']
    config.optimizer = sweep_config['parameters']['optimizer']
    config.clip = sweep_config['parameters']['clip']
    config.teacher_forcing_ratio = sweep_config['parameters']['teacher_forcing_ratio']
    config.decoder_learning_ratio = sweep_config['parameters']['decoder_learning_ratio']

   
   # Use the hyperparameters passed from the sweep
    learning_rate = config.learning_rate
    optimizer = config.optimizer
    clip = config.clip
    teacher_forcing_ratio = config.teacher_forcing_ratio
    decoder_learning_ratio = config.decoder_learning_ratio

    print('Building encoder and decoder ...')
    # Initialize word embeddings
    embedding = nn.Embedding(voc.num_words, hidden_size)
   
    # Initialize encoder & decoder models
    encoder = EncoderRNN(hidden_size, embedding, encoder_n_layers, dropout)
    decoder = LuongAttnDecoderRNN(attn_model, embedding, hidden_size, voc.num_words, decoder_n_layers, dropout)
   
    # Use appropriate device
    encoder = encoder.to(device)
    decoder = decoder.to(device)
    print('Models built and ready to go!')



    n_iteration = 4000
    print_every = 4000
    save_every=500
    loadFilename=None

    # Ensure dropout layers are in train mode
    encoder.train()
    decoder.train()

    # Initialize optimizers
    print('Building optimizers ...')
    if config.optimizer == 'adam':
      encoder_optimizer = optim.Adam(encoder.parameters(), lr=config.learning_rate)
      decoder_optimizer = optim.Adam(decoder.parameters(), lr=config.learning_rate * config.decoder_learning_ratio)
    else:
      encoder_optimizer = optim.SGD(encoder.parameters(), lr=config.learning_rate)
      decoder_optimizer = optim.SGD(decoder.parameters(), lr=config.learning_rate * config.decoder_learning_ratio)


    # If you have cuda, configure cuda to call
    for state in encoder_optimizer.state.values():
        for k, v in state.items():
            if isinstance(v, torch.Tensor):
                state[k] = v.cuda()

    for state in decoder_optimizer.state.values():
        for k, v in state.items():
            if isinstance(v, torch.Tensor):
                state[k] = v.cuda()


    # Run training iterations
    print("Starting Training!")
    loss = trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer,
              embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size,
              print_every, save_every, config.clip, corpus_name, loadFilename)

    # Log the loss and hyperparameters for this run
    wandb.log({'loss': loss})


    # Finish the WandB run
    wandb.finish()
  


#Initialize a new sweep
sweep_id = wandb.sweep(sweep_config, project='chatbot')

# Run the sweep
wandb.agent(sweep_id, function=wandb_train, count=50)
# Out:
# Create sweep with ID: sb7ajiux
# Sweep URL: https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux
# wandb: Agent Starting Run: homdgrzd with config:
# wandb: 	clip: 100
# wandb: 	decoder_learning_ratio: 3
# wandb: 	learning_rate: 0.00025
# wandb: 	optimizer: sgd
# wandb: 	teacher_forcing_ratio: 0.5
# Tracking run with wandb version 0.14.2
# Run data is saved locally in <code>/content/wandb/run-20230410_050202-homdgrzd</code>
# Syncing run <strong><a href='https://wandb.ai/rithviik/chatbot/runs/homdgrzd' target="_blank">ethereal-sweep-1</a></strong> to <a href='https://wandb.ai/rithviik/chatbot' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View project at <a href='https://wandb.ai/rithviik/chatbot' target="_blank">https://wandb.ai/rithviik/chatbot</a>
#  View sweep at <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View run at <a href='https://wandb.ai/rithviik/chatbot/runs/homdgrzd' target="_blank">https://wandb.ai/rithviik/chatbot/runs/homdgrzd</a>
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'clip' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'teacher_forcing_ratio' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'decoder_learning_ratio' was locked by 'sweep' (ignored update).
# Building encoder and decoder ...
# Models built and ready to go!
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 4000; Percent complete: 100.0%; Average loss: 5.2215
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss</td><td>5.22151</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ethereal-sweep-1</strong> at: <a href='https://wandb.ai/rithviik/chatbot/runs/homdgrzd' target="_blank">https://wandb.ai/rithviik/chatbot/runs/homdgrzd</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230410_050202-homdgrzd/logs</code>
# wandb: Agent Starting Run: zh4yzjnq with config:
# wandb: 	clip: 50
# wandb: 	decoder_learning_ratio: 3
# wandb: 	learning_rate: 0.00025
# wandb: 	optimizer: sgd
# wandb: 	teacher_forcing_ratio: 0.5
# Tracking run with wandb version 0.14.2
# Run data is saved locally in <code>/content/wandb/run-20230410_050527-zh4yzjnq</code>
# Syncing run <strong><a href='https://wandb.ai/rithviik/chatbot/runs/zh4yzjnq' target="_blank">rich-sweep-2</a></strong> to <a href='https://wandb.ai/rithviik/chatbot' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View project at <a href='https://wandb.ai/rithviik/chatbot' target="_blank">https://wandb.ai/rithviik/chatbot</a>
#  View sweep at <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View run at <a href='https://wandb.ai/rithviik/chatbot/runs/zh4yzjnq' target="_blank">https://wandb.ai/rithviik/chatbot/runs/zh4yzjnq</a>
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'clip' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'teacher_forcing_ratio' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'decoder_learning_ratio' was locked by 'sweep' (ignored update).
# Building encoder and decoder ...
# Models built and ready to go!
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 4000; Percent complete: 100.0%; Average loss: 5.2243
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss</td><td>5.22426</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">rich-sweep-2</strong> at: <a href='https://wandb.ai/rithviik/chatbot/runs/zh4yzjnq' target="_blank">https://wandb.ai/rithviik/chatbot/runs/zh4yzjnq</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230410_050527-zh4yzjnq/logs</code>
# wandb: Agent Starting Run: 0ck00r8p with config:
# wandb: 	clip: 0
# wandb: 	decoder_learning_ratio: 3
# wandb: 	learning_rate: 0.0001
# wandb: 	optimizer: sgd
# wandb: 	teacher_forcing_ratio: 0
# Tracking run with wandb version 0.14.2
# Run data is saved locally in <code>/content/wandb/run-20230410_050852-0ck00r8p</code>
# Syncing run <strong><a href='https://wandb.ai/rithviik/chatbot/runs/0ck00r8p' target="_blank">vocal-sweep-3</a></strong> to <a href='https://wandb.ai/rithviik/chatbot' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View project at <a href='https://wandb.ai/rithviik/chatbot' target="_blank">https://wandb.ai/rithviik/chatbot</a>
#  View sweep at <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View run at <a href='https://wandb.ai/rithviik/chatbot/runs/0ck00r8p' target="_blank">https://wandb.ai/rithviik/chatbot/runs/0ck00r8p</a>
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'clip' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'teacher_forcing_ratio' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'decoder_learning_ratio' was locked by 'sweep' (ignored update).
# Building encoder and decoder ...
# Models built and ready to go!
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 4000; Percent complete: 100.0%; Average loss: 8.9793
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss</td><td>8.97933</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">vocal-sweep-3</strong> at: <a href='https://wandb.ai/rithviik/chatbot/runs/0ck00r8p' target="_blank">https://wandb.ai/rithviik/chatbot/runs/0ck00r8p</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230410_050852-0ck00r8p/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: p8ijj3yr with config:
# wandb: 	clip: 25
# wandb: 	decoder_learning_ratio: 3
# wandb: 	learning_rate: 0.0001
# wandb: 	optimizer: adam
# wandb: 	teacher_forcing_ratio: 1
# Tracking run with wandb version 0.14.2
# Run data is saved locally in <code>/content/wandb/run-20230410_051222-p8ijj3yr</code>
# Syncing run <strong><a href='https://wandb.ai/rithviik/chatbot/runs/p8ijj3yr' target="_blank">wise-sweep-4</a></strong> to <a href='https://wandb.ai/rithviik/chatbot' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View project at <a href='https://wandb.ai/rithviik/chatbot' target="_blank">https://wandb.ai/rithviik/chatbot</a>
#  View sweep at <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View run at <a href='https://wandb.ai/rithviik/chatbot/runs/p8ijj3yr' target="_blank">https://wandb.ai/rithviik/chatbot/runs/p8ijj3yr</a>
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'clip' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'teacher_forcing_ratio' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'decoder_learning_ratio' was locked by 'sweep' (ignored update).
# Building encoder and decoder ...
# Models built and ready to go!
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 4000; Percent complete: 100.0%; Average loss: 4.1368
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss</td><td>4.13678</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">wise-sweep-4</strong> at: <a href='https://wandb.ai/rithviik/chatbot/runs/p8ijj3yr' target="_blank">https://wandb.ai/rithviik/chatbot/runs/p8ijj3yr</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230410_051222-p8ijj3yr/logs</code>
# wandb: Agent Starting Run: r6fdgues with config:
# wandb: 	clip: 25
# wandb: 	decoder_learning_ratio: 5
# wandb: 	learning_rate: 0.0001
# wandb: 	optimizer: sgd
# wandb: 	teacher_forcing_ratio: 0.5
# Tracking run with wandb version 0.14.2
# Run data is saved locally in <code>/content/wandb/run-20230410_051615-r6fdgues</code>
# Syncing run <strong><a href='https://wandb.ai/rithviik/chatbot/runs/r6fdgues' target="_blank">stilted-sweep-5</a></strong> to <a href='https://wandb.ai/rithviik/chatbot' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View project at <a href='https://wandb.ai/rithviik/chatbot' target="_blank">https://wandb.ai/rithviik/chatbot</a>
#  View sweep at <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View run at <a href='https://wandb.ai/rithviik/chatbot/runs/r6fdgues' target="_blank">https://wandb.ai/rithviik/chatbot/runs/r6fdgues</a>
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'clip' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'teacher_forcing_ratio' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'decoder_learning_ratio' was locked by 'sweep' (ignored update).
# Building encoder and decoder ...
# Models built and ready to go!
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 4000; Percent complete: 100.0%; Average loss: 5.4780
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss</td><td>5.47797</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">stilted-sweep-5</strong> at: <a href='https://wandb.ai/rithviik/chatbot/runs/r6fdgues' target="_blank">https://wandb.ai/rithviik/chatbot/runs/r6fdgues</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230410_051615-r6fdgues/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: o1t06f51 with config:
# wandb: 	clip: 25
# wandb: 	decoder_learning_ratio: 10
# wandb: 	learning_rate: 0.0005
# wandb: 	optimizer: adam
# wandb: 	teacher_forcing_ratio: 0.5
# Tracking run with wandb version 0.14.2
# Run data is saved locally in <code>/content/wandb/run-20230410_051945-o1t06f51</code>
# Syncing run <strong><a href='https://wandb.ai/rithviik/chatbot/runs/o1t06f51' target="_blank">rosy-sweep-6</a></strong> to <a href='https://wandb.ai/rithviik/chatbot' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View project at <a href='https://wandb.ai/rithviik/chatbot' target="_blank">https://wandb.ai/rithviik/chatbot</a>
#  View sweep at <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View run at <a href='https://wandb.ai/rithviik/chatbot/runs/o1t06f51' target="_blank">https://wandb.ai/rithviik/chatbot/runs/o1t06f51</a>
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'clip' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'teacher_forcing_ratio' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'decoder_learning_ratio' was locked by 'sweep' (ignored update).
# Building encoder and decoder ...
# Models built and ready to go!
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 4000; Percent complete: 100.0%; Average loss: 5.4295
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss</td><td>5.42953</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">rosy-sweep-6</strong> at: <a href='https://wandb.ai/rithviik/chatbot/runs/o1t06f51' target="_blank">https://wandb.ai/rithviik/chatbot/runs/o1t06f51</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230410_051945-o1t06f51/logs</code>
# wandb: Agent Starting Run: 738qrzbc with config:
# wandb: 	clip: 100
# wandb: 	decoder_learning_ratio: 3
# wandb: 	learning_rate: 0.0001
# wandb: 	optimizer: adam
# wandb: 	teacher_forcing_ratio: 0
# Tracking run with wandb version 0.14.2
# Run data is saved locally in <code>/content/wandb/run-20230410_052338-738qrzbc</code>
# Syncing run <strong><a href='https://wandb.ai/rithviik/chatbot/runs/738qrzbc' target="_blank">sweepy-sweep-7</a></strong> to <a href='https://wandb.ai/rithviik/chatbot' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View project at <a href='https://wandb.ai/rithviik/chatbot' target="_blank">https://wandb.ai/rithviik/chatbot</a>
#  View sweep at <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View run at <a href='https://wandb.ai/rithviik/chatbot/runs/738qrzbc' target="_blank">https://wandb.ai/rithviik/chatbot/runs/738qrzbc</a>
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'clip' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'teacher_forcing_ratio' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'decoder_learning_ratio' was locked by 'sweep' (ignored update).
# Building encoder and decoder ...
# Models built and ready to go!
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 4000; Percent complete: 100.0%; Average loss: 4.1495
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss</td><td>4.14949</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">sweepy-sweep-7</strong> at: <a href='https://wandb.ai/rithviik/chatbot/runs/738qrzbc' target="_blank">https://wandb.ai/rithviik/chatbot/runs/738qrzbc</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230410_052338-738qrzbc/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: q33fk9rs with config:
# wandb: 	clip: 50
# wandb: 	decoder_learning_ratio: 5
# wandb: 	learning_rate: 0.001
# wandb: 	optimizer: sgd
# wandb: 	teacher_forcing_ratio: 0
# Tracking run with wandb version 0.14.2
# Run data is saved locally in <code>/content/wandb/run-20230410_052739-q33fk9rs</code>
# Syncing run <strong><a href='https://wandb.ai/rithviik/chatbot/runs/q33fk9rs' target="_blank">lemon-sweep-8</a></strong> to <a href='https://wandb.ai/rithviik/chatbot' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View project at <a href='https://wandb.ai/rithviik/chatbot' target="_blank">https://wandb.ai/rithviik/chatbot</a>
#  View sweep at <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View run at <a href='https://wandb.ai/rithviik/chatbot/runs/q33fk9rs' target="_blank">https://wandb.ai/rithviik/chatbot/runs/q33fk9rs</a>
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'clip' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'teacher_forcing_ratio' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'decoder_learning_ratio' was locked by 'sweep' (ignored update).
# Building encoder and decoder ...
# Models built and ready to go!
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 4000; Percent complete: 100.0%; Average loss: 4.7025
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss</td><td>4.70245</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">lemon-sweep-8</strong> at: <a href='https://wandb.ai/rithviik/chatbot/runs/q33fk9rs' target="_blank">https://wandb.ai/rithviik/chatbot/runs/q33fk9rs</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230410_052739-q33fk9rs/logs</code>
# wandb: Agent Starting Run: lgyqxjps with config:
# wandb: 	clip: 25
# wandb: 	decoder_learning_ratio: 5
# wandb: 	learning_rate: 0.001
# wandb: 	optimizer: sgd
# wandb: 	teacher_forcing_ratio: 0
# Tracking run with wandb version 0.14.2
# Run data is saved locally in <code>/content/wandb/run-20230410_053104-lgyqxjps</code>
# Syncing run <strong><a href='https://wandb.ai/rithviik/chatbot/runs/lgyqxjps' target="_blank">wobbly-sweep-9</a></strong> to <a href='https://wandb.ai/rithviik/chatbot' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View project at <a href='https://wandb.ai/rithviik/chatbot' target="_blank">https://wandb.ai/rithviik/chatbot</a>
#  View sweep at <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View run at <a href='https://wandb.ai/rithviik/chatbot/runs/lgyqxjps' target="_blank">https://wandb.ai/rithviik/chatbot/runs/lgyqxjps</a>
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'clip' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'teacher_forcing_ratio' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'decoder_learning_ratio' was locked by 'sweep' (ignored update).
# Building encoder and decoder ...
# Models built and ready to go!
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 4000; Percent complete: 100.0%; Average loss: 4.7185
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss</td><td>4.7185</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">wobbly-sweep-9</strong> at: <a href='https://wandb.ai/rithviik/chatbot/runs/lgyqxjps' target="_blank">https://wandb.ai/rithviik/chatbot/runs/lgyqxjps</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230410_053104-lgyqxjps/logs</code>
# wandb: Agent Starting Run: 8hxp7j7b with config:
# wandb: 	clip: 100
# wandb: 	decoder_learning_ratio: 1
# wandb: 	learning_rate: 0.0005
# wandb: 	optimizer: sgd
# wandb: 	teacher_forcing_ratio: 0
# Tracking run with wandb version 0.14.2
# Run data is saved locally in <code>/content/wandb/run-20230410_053429-8hxp7j7b</code>
# Syncing run <strong><a href='https://wandb.ai/rithviik/chatbot/runs/8hxp7j7b' target="_blank">spring-sweep-10</a></strong> to <a href='https://wandb.ai/rithviik/chatbot' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View project at <a href='https://wandb.ai/rithviik/chatbot' target="_blank">https://wandb.ai/rithviik/chatbot</a>
#  View sweep at <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View run at <a href='https://wandb.ai/rithviik/chatbot/runs/8hxp7j7b' target="_blank">https://wandb.ai/rithviik/chatbot/runs/8hxp7j7b</a>
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'clip' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'teacher_forcing_ratio' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'decoder_learning_ratio' was locked by 'sweep' (ignored update).
# Building encoder and decoder ...
# Models built and ready to go!
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 4000; Percent complete: 100.0%; Average loss: 5.3595
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss</td><td>5.35952</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">spring-sweep-10</strong> at: <a href='https://wandb.ai/rithviik/chatbot/runs/8hxp7j7b' target="_blank">https://wandb.ai/rithviik/chatbot/runs/8hxp7j7b</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230410_053429-8hxp7j7b/logs</code>
# wandb: Agent Starting Run: 83pmnz69 with config:
# wandb: 	clip: 100
# wandb: 	decoder_learning_ratio: 5
# wandb: 	learning_rate: 0.00025
# wandb: 	optimizer: adam
# wandb: 	teacher_forcing_ratio: 0
# Tracking run with wandb version 0.14.2
# Run data is saved locally in <code>/content/wandb/run-20230410_053755-83pmnz69</code>
# Syncing run <strong><a href='https://wandb.ai/rithviik/chatbot/runs/83pmnz69' target="_blank">devout-sweep-11</a></strong> to <a href='https://wandb.ai/rithviik/chatbot' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View project at <a href='https://wandb.ai/rithviik/chatbot' target="_blank">https://wandb.ai/rithviik/chatbot</a>
#  View sweep at <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View run at <a href='https://wandb.ai/rithviik/chatbot/runs/83pmnz69' target="_blank">https://wandb.ai/rithviik/chatbot/runs/83pmnz69</a>
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'clip' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'teacher_forcing_ratio' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'decoder_learning_ratio' was locked by 'sweep' (ignored update).
# Building encoder and decoder ...
# Models built and ready to go!
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 4000; Percent complete: 100.0%; Average loss: 3.9008
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss</td><td>3.90075</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">devout-sweep-11</strong> at: <a href='https://wandb.ai/rithviik/chatbot/runs/83pmnz69' target="_blank">https://wandb.ai/rithviik/chatbot/runs/83pmnz69</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230410_053755-83pmnz69/logs</code>
# wandb: Agent Starting Run: kmwsabya with config:
# wandb: 	clip: 50
# wandb: 	decoder_learning_ratio: 10
# wandb: 	learning_rate: 0.001
# wandb: 	optimizer: adam
# wandb: 	teacher_forcing_ratio: 1
# Tracking run with wandb version 0.14.2
# Run data is saved locally in <code>/content/wandb/run-20230410_054150-kmwsabya</code>
# Syncing run <strong><a href='https://wandb.ai/rithviik/chatbot/runs/kmwsabya' target="_blank">easy-sweep-12</a></strong> to <a href='https://wandb.ai/rithviik/chatbot' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View project at <a href='https://wandb.ai/rithviik/chatbot' target="_blank">https://wandb.ai/rithviik/chatbot</a>
#  View sweep at <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View run at <a href='https://wandb.ai/rithviik/chatbot/runs/kmwsabya' target="_blank">https://wandb.ai/rithviik/chatbot/runs/kmwsabya</a>
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'clip' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'teacher_forcing_ratio' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'decoder_learning_ratio' was locked by 'sweep' (ignored update).
# Building encoder and decoder ...
# Models built and ready to go!
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 4000; Percent complete: 100.0%; Average loss: nan
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss</td><td>nan</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">easy-sweep-12</strong> at: <a href='https://wandb.ai/rithviik/chatbot/runs/kmwsabya' target="_blank">https://wandb.ai/rithviik/chatbot/runs/kmwsabya</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230410_054150-kmwsabya/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: se4mme15 with config:
# wandb: 	clip: 100
# wandb: 	decoder_learning_ratio: 1
# wandb: 	learning_rate: 0.001
# wandb: 	optimizer: sgd
# wandb: 	teacher_forcing_ratio: 0.5
# Tracking run with wandb version 0.14.2
# Run data is saved locally in <code>/content/wandb/run-20230410_054552-se4mme15</code>
# Syncing run <strong><a href='https://wandb.ai/rithviik/chatbot/runs/se4mme15' target="_blank">efficient-sweep-13</a></strong> to <a href='https://wandb.ai/rithviik/chatbot' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View project at <a href='https://wandb.ai/rithviik/chatbot' target="_blank">https://wandb.ai/rithviik/chatbot</a>
#  View sweep at <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View run at <a href='https://wandb.ai/rithviik/chatbot/runs/se4mme15' target="_blank">https://wandb.ai/rithviik/chatbot/runs/se4mme15</a>
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'clip' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'teacher_forcing_ratio' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'decoder_learning_ratio' was locked by 'sweep' (ignored update).
# Building encoder and decoder ...
# Models built and ready to go!
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 4000; Percent complete: 100.0%; Average loss: 5.0635
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss</td><td>5.06353</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">efficient-sweep-13</strong> at: <a href='https://wandb.ai/rithviik/chatbot/runs/se4mme15' target="_blank">https://wandb.ai/rithviik/chatbot/runs/se4mme15</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230410_054552-se4mme15/logs</code>
# wandb: Agent Starting Run: 1nm0luq3 with config:
# wandb: 	clip: 50
# wandb: 	decoder_learning_ratio: 3
# wandb: 	learning_rate: 0.0001
# wandb: 	optimizer: sgd
# wandb: 	teacher_forcing_ratio: 1
# Tracking run with wandb version 0.14.2
# Run data is saved locally in <code>/content/wandb/run-20230410_054917-1nm0luq3</code>
# Syncing run <strong><a href='https://wandb.ai/rithviik/chatbot/runs/1nm0luq3' target="_blank">absurd-sweep-14</a></strong> to <a href='https://wandb.ai/rithviik/chatbot' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View project at <a href='https://wandb.ai/rithviik/chatbot' target="_blank">https://wandb.ai/rithviik/chatbot</a>
#  View sweep at <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View run at <a href='https://wandb.ai/rithviik/chatbot/runs/1nm0luq3' target="_blank">https://wandb.ai/rithviik/chatbot/runs/1nm0luq3</a>
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'clip' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'teacher_forcing_ratio' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'decoder_learning_ratio' was locked by 'sweep' (ignored update).
# Building encoder and decoder ...
# Models built and ready to go!
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 4000; Percent complete: 100.0%; Average loss: 5.8100
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss</td><td>5.80997</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">absurd-sweep-14</strong> at: <a href='https://wandb.ai/rithviik/chatbot/runs/1nm0luq3' target="_blank">https://wandb.ai/rithviik/chatbot/runs/1nm0luq3</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230410_054917-1nm0luq3/logs</code>
# wandb: Agent Starting Run: klnpzem2 with config:
# wandb: 	clip: 0
# wandb: 	decoder_learning_ratio: 1
# wandb: 	learning_rate: 0.001
# wandb: 	optimizer: sgd
# wandb: 	teacher_forcing_ratio: 0
# Tracking run with wandb version 0.14.2
# Run data is saved locally in <code>/content/wandb/run-20230410_055241-klnpzem2</code>
# Syncing run <strong><a href='https://wandb.ai/rithviik/chatbot/runs/klnpzem2' target="_blank">golden-sweep-15</a></strong> to <a href='https://wandb.ai/rithviik/chatbot' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View project at <a href='https://wandb.ai/rithviik/chatbot' target="_blank">https://wandb.ai/rithviik/chatbot</a>
#  View sweep at <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View run at <a href='https://wandb.ai/rithviik/chatbot/runs/klnpzem2' target="_blank">https://wandb.ai/rithviik/chatbot/runs/klnpzem2</a>
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'clip' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'teacher_forcing_ratio' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'decoder_learning_ratio' was locked by 'sweep' (ignored update).
# Building encoder and decoder ...
# Models built and ready to go!
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 4000; Percent complete: 100.0%; Average loss: 8.9554
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss</td><td>8.9554</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">golden-sweep-15</strong> at: <a href='https://wandb.ai/rithviik/chatbot/runs/klnpzem2' target="_blank">https://wandb.ai/rithviik/chatbot/runs/klnpzem2</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230410_055241-klnpzem2/logs</code>
# wandb: Agent Starting Run: 4pl3xief with config:
# wandb: 	clip: 0
# wandb: 	decoder_learning_ratio: 5
# wandb: 	learning_rate: 0.0005
# wandb: 	optimizer: sgd
# wandb: 	teacher_forcing_ratio: 1
# Tracking run with wandb version 0.14.2
# Run data is saved locally in <code>/content/wandb/run-20230410_055605-4pl3xief</code>
# Syncing run <strong><a href='https://wandb.ai/rithviik/chatbot/runs/4pl3xief' target="_blank">pious-sweep-16</a></strong> to <a href='https://wandb.ai/rithviik/chatbot' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View project at <a href='https://wandb.ai/rithviik/chatbot' target="_blank">https://wandb.ai/rithviik/chatbot</a>
#  View sweep at <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View run at <a href='https://wandb.ai/rithviik/chatbot/runs/4pl3xief' target="_blank">https://wandb.ai/rithviik/chatbot/runs/4pl3xief</a>
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'clip' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'teacher_forcing_ratio' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'decoder_learning_ratio' was locked by 'sweep' (ignored update).
# Building encoder and decoder ...
# Models built and ready to go!
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 4000; Percent complete: 100.0%; Average loss: 8.9655
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss</td><td>8.96547</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">pious-sweep-16</strong> at: <a href='https://wandb.ai/rithviik/chatbot/runs/4pl3xief' target="_blank">https://wandb.ai/rithviik/chatbot/runs/4pl3xief</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230410_055605-4pl3xief/logs</code>
# wandb: Agent Starting Run: diibred9 with config:
# wandb: 	clip: 25
# wandb: 	decoder_learning_ratio: 3
# wandb: 	learning_rate: 0.001
# wandb: 	optimizer: adam
# wandb: 	teacher_forcing_ratio: 0
# Tracking run with wandb version 0.14.2
# Run data is saved locally in <code>/content/wandb/run-20230410_055926-diibred9</code>
# Syncing run <strong><a href='https://wandb.ai/rithviik/chatbot/runs/diibred9' target="_blank">glad-sweep-17</a></strong> to <a href='https://wandb.ai/rithviik/chatbot' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View project at <a href='https://wandb.ai/rithviik/chatbot' target="_blank">https://wandb.ai/rithviik/chatbot</a>
#  View sweep at <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View run at <a href='https://wandb.ai/rithviik/chatbot/runs/diibred9' target="_blank">https://wandb.ai/rithviik/chatbot/runs/diibred9</a>
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'clip' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'teacher_forcing_ratio' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'decoder_learning_ratio' was locked by 'sweep' (ignored update).
# Building encoder and decoder ...
# Models built and ready to go!
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 4000; Percent complete: 100.0%; Average loss: 4.6065
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# ...
#  View run at <a href='https://wandb.ai/rithviik/chatbot/runs/31rkynjs' target="_blank">https://wandb.ai/rithviik/chatbot/runs/31rkynjs</a>
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'clip' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'teacher_forcing_ratio' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'decoder_learning_ratio' was locked by 'sweep' (ignored update).
# Building encoder and decoder ...
# Models built and ready to go!
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 4000; Percent complete: 100.0%; Average loss: 4.1505
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss</td><td>4.15049</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">jolly-sweep-45</strong> at: <a href='https://wandb.ai/rithviik/chatbot/runs/31rkynjs' target="_blank">https://wandb.ai/rithviik/chatbot/runs/31rkynjs</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230410_074200-31rkynjs/logs</code>
# wandb: Agent Starting Run: mc6lsciq with config:
# wandb: 	clip: 0
# wandb: 	decoder_learning_ratio: 3
# wandb: 	learning_rate: 0.0005
# wandb: 	optimizer: sgd
# wandb: 	teacher_forcing_ratio: 0
# Tracking run with wandb version 0.14.2
# Run data is saved locally in <code>/content/wandb/run-20230410_074557-mc6lsciq</code>
# Syncing run <strong><a href='https://wandb.ai/rithviik/chatbot/runs/mc6lsciq' target="_blank">clear-sweep-46</a></strong> to <a href='https://wandb.ai/rithviik/chatbot' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View project at <a href='https://wandb.ai/rithviik/chatbot' target="_blank">https://wandb.ai/rithviik/chatbot</a>
#  View sweep at <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View run at <a href='https://wandb.ai/rithviik/chatbot/runs/mc6lsciq' target="_blank">https://wandb.ai/rithviik/chatbot/runs/mc6lsciq</a>
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'clip' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'teacher_forcing_ratio' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'decoder_learning_ratio' was locked by 'sweep' (ignored update).
# Building encoder and decoder ...
# Models built and ready to go!
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 4000; Percent complete: 100.0%; Average loss: 8.9736
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss</td><td>8.97357</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">clear-sweep-46</strong> at: <a href='https://wandb.ai/rithviik/chatbot/runs/mc6lsciq' target="_blank">https://wandb.ai/rithviik/chatbot/runs/mc6lsciq</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230410_074557-mc6lsciq/logs</code>
# wandb: Agent Starting Run: 4yglug5f with config:
# wandb: 	clip: 50
# wandb: 	decoder_learning_ratio: 10
# wandb: 	learning_rate: 0.0001
# wandb: 	optimizer: sgd
# wandb: 	teacher_forcing_ratio: 1
# Tracking run with wandb version 0.14.2
# Run data is saved locally in <code>/content/wandb/run-20230410_074921-4yglug5f</code>
# Syncing run <strong><a href='https://wandb.ai/rithviik/chatbot/runs/4yglug5f' target="_blank">apricot-sweep-47</a></strong> to <a href='https://wandb.ai/rithviik/chatbot' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View project at <a href='https://wandb.ai/rithviik/chatbot' target="_blank">https://wandb.ai/rithviik/chatbot</a>
#  View sweep at <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View run at <a href='https://wandb.ai/rithviik/chatbot/runs/4yglug5f' target="_blank">https://wandb.ai/rithviik/chatbot/runs/4yglug5f</a>
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'clip' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'teacher_forcing_ratio' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'decoder_learning_ratio' was locked by 'sweep' (ignored update).
# Building encoder and decoder ...
# Models built and ready to go!
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 4000; Percent complete: 100.0%; Average loss: 5.1566
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss</td><td>5.15657</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">apricot-sweep-47</strong> at: <a href='https://wandb.ai/rithviik/chatbot/runs/4yglug5f' target="_blank">https://wandb.ai/rithviik/chatbot/runs/4yglug5f</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230410_074921-4yglug5f/logs</code>
# wandb: Agent Starting Run: ftv3p0xd with config:
# wandb: 	clip: 100
# wandb: 	decoder_learning_ratio: 5
# wandb: 	learning_rate: 0.00025
# wandb: 	optimizer: adam
# wandb: 	teacher_forcing_ratio: 1
# Tracking run with wandb version 0.14.2
# Run data is saved locally in <code>/content/wandb/run-20230410_075246-ftv3p0xd</code>
# Syncing run <strong><a href='https://wandb.ai/rithviik/chatbot/runs/ftv3p0xd' target="_blank">laced-sweep-48</a></strong> to <a href='https://wandb.ai/rithviik/chatbot' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View project at <a href='https://wandb.ai/rithviik/chatbot' target="_blank">https://wandb.ai/rithviik/chatbot</a>
#  View sweep at <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View run at <a href='https://wandb.ai/rithviik/chatbot/runs/ftv3p0xd' target="_blank">https://wandb.ai/rithviik/chatbot/runs/ftv3p0xd</a>
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'clip' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'teacher_forcing_ratio' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'decoder_learning_ratio' was locked by 'sweep' (ignored update).
# Building encoder and decoder ...
# Models built and ready to go!
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 4000; Percent complete: 100.0%; Average loss: 3.8958
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss</td><td>3.89576</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">laced-sweep-48</strong> at: <a href='https://wandb.ai/rithviik/chatbot/runs/ftv3p0xd' target="_blank">https://wandb.ai/rithviik/chatbot/runs/ftv3p0xd</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230410_075246-ftv3p0xd/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 72dh4vi1 with config:
# wandb: 	clip: 50
# wandb: 	decoder_learning_ratio: 3
# wandb: 	learning_rate: 0.00025
# wandb: 	optimizer: adam
# wandb: 	teacher_forcing_ratio: 1
# Tracking run with wandb version 0.14.2
# Run data is saved locally in <code>/content/wandb/run-20230410_075647-72dh4vi1</code>
# Syncing run <strong><a href='https://wandb.ai/rithviik/chatbot/runs/72dh4vi1' target="_blank">dashing-sweep-49</a></strong> to <a href='https://wandb.ai/rithviik/chatbot' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View project at <a href='https://wandb.ai/rithviik/chatbot' target="_blank">https://wandb.ai/rithviik/chatbot</a>
#  View sweep at <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View run at <a href='https://wandb.ai/rithviik/chatbot/runs/72dh4vi1' target="_blank">https://wandb.ai/rithviik/chatbot/runs/72dh4vi1</a>
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'clip' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'teacher_forcing_ratio' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'decoder_learning_ratio' was locked by 'sweep' (ignored update).
# Building encoder and decoder ...
# Models built and ready to go!
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 4000; Percent complete: 100.0%; Average loss: 3.9304
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss</td><td>3.93039</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">dashing-sweep-49</strong> at: <a href='https://wandb.ai/rithviik/chatbot/runs/72dh4vi1' target="_blank">https://wandb.ai/rithviik/chatbot/runs/72dh4vi1</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230410_075647-72dh4vi1/logs</code>
# wandb: Agent Starting Run: 1czqoluu with config:
# wandb: 	clip: 50
# wandb: 	decoder_learning_ratio: 5
# wandb: 	learning_rate: 0.0005
# wandb: 	optimizer: adam
# wandb: 	teacher_forcing_ratio: 0
# Tracking run with wandb version 0.14.2
# Run data is saved locally in <code>/content/wandb/run-20230410_080039-1czqoluu</code>
# Syncing run <strong><a href='https://wandb.ai/rithviik/chatbot/runs/1czqoluu' target="_blank">chocolate-sweep-50</a></strong> to <a href='https://wandb.ai/rithviik/chatbot' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View project at <a href='https://wandb.ai/rithviik/chatbot' target="_blank">https://wandb.ai/rithviik/chatbot</a>
#  View sweep at <a href='https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux' target="_blank">https://wandb.ai/rithviik/chatbot/sweeps/sb7ajiux</a>
#  View run at <a href='https://wandb.ai/rithviik/chatbot/runs/1czqoluu' target="_blank">https://wandb.ai/rithviik/chatbot/runs/1czqoluu</a>
# wandb: WARNING Config item 'learning_rate' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'optimizer' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'clip' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'teacher_forcing_ratio' was locked by 'sweep' (ignored update).
# wandb: WARNING Config item 'decoder_learning_ratio' was locked by 'sweep' (ignored update).
# Building encoder and decoder ...
# Models built and ready to go!
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 4000; Percent complete: 100.0%; Average loss: 4.4805
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss</td><td>4.4805</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">chocolate-sweep-50</strong> at: <a href='https://wandb.ai/rithviik/chatbot/runs/1czqoluu' target="_blank">https://wandb.ai/rithviik/chatbot/runs/1czqoluu</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230410_080039-1czqoluu/logs</code>

# %% [markdown]
# **Q.5:**
#
# On seeing the feature importance of W&B, it can be seen that out of all the config parameters, the SGD optimiser had a highest positive correlation of 0.316 with the loss metric. The Adam optimiser instead had a negative correlation of -0.316 with the loss metric. This shows that adam optimiser worked well with the model as the correlation indicates that the higher the correlation, higher the loss metric. We are trying to minimise the loss so a negative correlation indicates better suitability. Also in terms of importance of hyperparameters, the clip has the highest importance and highest negative correlation of -0.723 indicating that it has a major role in determining convergence.  Also following this would be the learning rate and runtime which is also relatively negatively correlated. The other metrics do have a lesser negative correlation and so we can conclude that the primary hyperparameters that brought about convergence are learning rate and clip.
# ![Param_Imp.png](data:image/png;base64,...)

# %% [markdown]
# ***Loss Log***
# ![Loss_Log.png](data:image/png;base64,...)

# %% [markdown]
# ***HYPERPARAMETER SWEEP***
#
# The best hyperparameters were clip: 100, decoder_learning_ratio: 5,
#
# teacher_forcing_ratio: 0, learning_rate: 0.00025, optimzer: adam for a loss of 3.901
#
#
# ![Param_Graph.png](data:image/png;base64,...)

# %% [markdown]
# ***Q.6***

# %%
import torchvision.models as models
from torch.profiler import profile, record_function, ProfilerActivity


with profile(activities=[
        ProfilerActivity.CPU, ProfilerActivity.CUDA], profile_memory=True, record_shapes=True) as prof:
    with record_function("model_inference"):

      
      # Configure models , Configure training/optimization
      model_name = 'cb_model_bestloss'
      attn_model = 'dot'
      hidden_size = 500
      encoder_n_layers = 2
      decoder_n_layers = 2
      dropout = 0.1
      batch_size = 64
      learning_rate = 0.00025
      clip =100
      teacher_forcing_ratio =0
      decoder_learning_ratio =5
      n_iteration = 4000
      print_every = 500





      # Initialize word embeddings
      embedding = nn.Embedding(voc.num_words, hidden_size)

      # Initialize encoder & decoder models
      encoder = EncoderRNN(hidden_size, embedding, encoder_n_layers, dropout)
      decoder = LuongAttnDecoderRNN(attn_model, embedding, hidden_size, voc.num_words, decoder_n_layers, dropout)

      # Use appropriate device
      encoder = encoder.to(device)
      decoder = decoder.to(device)
    





      encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
      decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)


      # If you have cuda, configure cuda to call
      for state in encoder_optimizer.state.values():
          for k, v in state.items():
              if isinstance(v, torch.Tensor):
                  state[k] = v.cuda()

      for state in decoder_optimizer.state.values():
          for k, v in state.items():
              if isinstance(v, torch.Tensor):
                  state[k] = v.cuda()

      # Set dropout layers to eval mode
      encoder.eval()
      decoder.eval()

      # Initialize search module
      searcher = GreedySearchDecoder(encoder, decoder)

      # Begin chatting (uncomment and run the following line to begin)
      evaluateInput(encoder, decoder, searcher, voc)
# Out:
# > hi
# Bot: yell kicked kicked kind pumpkin riders examined limb examined indeed
# > quit

# %%
#Time Consumption
print(prof.key_averages().table(sort_by="cuda_time_total", row_limit=10))
# Out:
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg       CPU Mem  Self CPU Mem      CUDA Mem  Self CUDA Mem    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                         model_inference        88.25%        6.869s       100.00%        7.784s        7.784s       0.000us         0.00%      20.653ms      20.653ms           0 b     -71.95 Mb      81.04 Mb    -946.50 Kb             1
#                                             aten::copy_         0.01%     783.000us         0.45%      35.009ms     636.527us      16.704ms        80.88%      16.704ms     303.709us           0 b           0 b           0 b           0 b            55
#                                                aten::to         0.04%       2.973ms         0.50%      39.250ms       1.121ms       0.000us         0.00%      16.163ms     461.800us           0 b           0 b      74.72 Mb           0 b            35
#                                          aten::_to_copy         0.01%     449.000us         0.47%      36.277ms       1.209ms       0.000us         0.00%      16.163ms     538.767us           0 b           0 b      74.72 Mb           0 b            30
#                        Memcpy HtoD (Pageable -> Device)         0.00%       0.000us         0.00%       0.000us       0.000us      16.163ms        78.26%      16.163ms     538.767us           0 b           0 b           0 b           0 b            30
#                                               aten::gru         0.01%     695.000us         6.45%     502.288ms      45.663ms       0.000us         0.00%       1.706ms     155.091us           0 b           0 b      76.00 Kb           0 b            11
#                                        aten::_cudnn_rnn         6.43%     500.196ms         6.44%     501.409ms      45.583ms       1.706ms         8.26%       1.706ms     155.091us           0 b           0 b      76.00 Kb    -335.30 Mb            11
# void gemv2T_kernel_val<int, int, float, float, float...         0.00%       0.000us         0.00%       0.000us       0.000us       1.300ms         6.29%       1.300ms      27.083us           0 b           0 b           0 b           0 b            48
#                                             aten::addmm         0.01%     835.000us         0.01%       1.121ms      56.050us       1.093ms         5.29%       1.093ms      54.650us           0 b           0 b     330.00 Kb     -19.68 Mb            20
#                                            aten::linear         0.00%     172.000us         0.02%       1.365ms      68.250us       0.000us         0.00%     984.000us      49.200us           0 b           0 b     330.00 Kb      33.00 Kb            20
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 7.784s
# Self CUDA time total: 20.653ms

# %%
#Memory Consumption
print(prof.key_averages().table(sort_by="cuda_memory_usage", row_limit=10))
# Out:
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg       CPU Mem  Self CPU Mem      CUDA Mem  Self CUDA Mem    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                             aten::empty         0.02%       1.197ms         0.02%       1.769ms      10.988us       0.000us         0.00%       0.000us       0.000us      71.95 Mb      71.95 Mb     395.51 Mb     395.51 Mb           161
#                                         model_inference        88.25%        6.869s       100.00%        7.784s        7.784s       0.000us         0.00%      20.653ms      20.653ms           0 b     -71.95 Mb      81.04 Mb    -946.50 Kb             1
#                                                aten::to         0.04%       2.973ms         0.50%      39.250ms       1.121ms       0.000us         0.00%      16.163ms     461.800us           0 b           0 b      74.72 Mb           0 b            35
#                                          aten::_to_copy         0.01%     449.000us         0.47%      36.277ms       1.209ms       0.000us         0.00%      16.163ms     538.767us           0 b           0 b      74.72 Mb           0 b            30
#                                     aten::empty_strided         0.01%     506.000us         0.02%       1.439ms      47.967us       0.000us         0.00%       0.000us       0.000us           0 b           0 b      74.72 Mb      74.72 Mb            30
#                                             aten::zeros         0.00%      46.000us         0.01%     763.000us     152.600us       0.000us         0.00%     183.000us      36.600us           0 b           0 b      40.13 Mb           0 b             5
#                                               aten::bmm         0.12%       9.271ms         0.12%       9.624ms     962.400us      50.000us         0.24%      50.000us       5.000us           0 b           0 b       8.14 Mb       8.14 Mb            10
#                                            aten::linear         0.00%     172.000us         0.02%       1.365ms      68.250us       0.000us         0.00%     984.000us      49.200us           0 b           0 b     330.00 Kb      33.00 Kb            20
#                                             aten::addmm         0.01%     835.000us         0.01%       1.121ms      56.050us       1.093ms         5.29%       1.093ms      54.650us           0 b           0 b     330.00 Kb     -19.68 Mb            20
#                                           aten::softmax         0.00%     162.000us         0.03%       2.060ms     103.000us       0.000us         0.00%     247.000us      12.350us           0 b           0 b     315.00 Kb           0 b            20
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 7.784s
# Self CUDA time total: 20.653ms

# %% [markdown]
# ***Q.7***

# %%
prof.export_chrome_trace("trace.json")

# %% [markdown]
# ![trace.png](data:image/png;base64,...)

# %% [markdown]
#  ***Q.8***

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Configure models , Configure training/optimization
model_name = 'cb_model_BEST_LOSS'
attn_model = 'dot'
hidden_size = 500
encoder_n_layers = 2
decoder_n_layers = 2
dropout = 0.1
batch_size = 64
learning_rate = 0.00025

clip =100
teacher_forcing_ratio =0
decoder_learning_ratio =5
n_iteration = 4000
print_every = 1000
save_every = 4000
loadFilename = None

print('Building encoder and decoder ...')
# Initialize word embeddings
embedding = nn.Embedding(voc.num_words, hidden_size)

# Initialize encoder & decoder models
encoder = EncoderRNN(hidden_size, embedding, encoder_n_layers, dropout)
decoder = LuongAttnDecoderRNN(attn_model, embedding, hidden_size, voc.num_words, decoder_n_layers, dropout)

# Use appropriate device
encoder = encoder.to(device)
decoder = decoder.to(device)
print('Models built and ready to go!')

# Initialize optimizers
print('Building optimizers ...')
encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)


# If you have cuda, configure cuda to call
for state in encoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.cuda()

for state in decoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.cuda()




# Ensure dropout layers are in train mode
encoder.train()
decoder.train()

# Initialize optimizers
print('Building optimizers ...')
encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)


# If you have cuda, configure cuda to call
for state in encoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.cuda()

for state in decoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.cuda()

# Run training iterations
print("Starting Training!")
trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer,
           embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size,
           print_every, save_every, clip, corpus_name, loadFilename)
# Out:
# Building encoder and decoder ...
# Models built and ready to go!
# Building optimizers ...
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 1000; Percent complete: 25.0%; Average loss: 4.7342
# Iteration: 2000; Percent complete: 50.0%; Average loss: 4.3878
# Iteration: 3000; Percent complete: 75.0%; Average loss: 4.0849
# Iteration: 4000; Percent complete: 100.0%; Average loss: 3.7478
# 4.238691599317135

# %% [markdown]
# As we can see the average loss of 3.7478 at 4000 iterations is around the same loss range we got in the hyperparameter sweep

# %% [markdown]
# **PROBLEM2**

# %% [markdown]
# **Q.1**
#
# In PyTorch, tracing and scripting are two ways to convert PyTorch models into TorchScript, which is a high-performance serialization and deployment format for PyTorch models.
#
# Tracing involves recording the operations performed by a PyTorch model during a forward pass on a set of inputs. This creates a trace of the model's execution as a graph structure, which can be saved as a TorchScript file. This approach is useful when the model has a fixed input shape and the control flow is static, which is typical for many deep learning models. Tracing is often used for models that are used for inference, and not trained further.
#
# Scripting involves writing the PyTorch model as a script using Python syntax, and then converting it into TorchScript. This approach is useful when the model has a dynamic input shape, and the control flow is more complex, with conditional statements and loops. In scripting, one can use Python's control flow constructs, and the resulting script can be converted to TorchScript. Scripting is often used for models that require further training, such as reinforcement learning or transfer learning.
#
# TorchScript allows combining tracing and scripting to leverage their respective strengths and optimize the performance of PyTorch models. Tracing optimizes the performance of the static parts of the model, while scripting handles the dynamic parts of the model. TorchScript is a powerful tool for optimizing PyTorch models for deployment on various platforms, including mobile devices and cloud-based servers.

# %% [markdown]
# **Q.2**
#
# The chatbot model is based on a sequence-to-sequence (Seq2Seq) model using an encoder-decoder architecture with attention. To enable scripting in this chatbot model, we need to make the following changes:
#
# 1. ***Convert the model to use CPU instead of GPU***: To allow for scripting, the model needs to be moved from GPU to CPU. This can be done by calling the to('cpu') method on the model and its associated tensors.
#
# 2. ***Trace the encoder and decoder models***: The encoder and decoder models need to be traced using the torch.jit.trace function. This function takes a model and a set of example inputs, and creates a scriptable version of the model. In this case, the example inputs are a sequence of words and its associated length.
#
# 3. ***Modify the searcher module***: The searcher module needs to be modified to use the scriptable encoder and decoder models. This can be done by passing the traced encoder and decoder models to the GreedySearchDecoder constructor. The GreedySearchDecoder module takes care of running the encoder and decoder models in sequence, using the output of the encoder as input to the decoder.
#
# 4. ***Wrap the searcher module in a script***: The final step is to wrap the searcher module in a torch.jit.script call, which creates a scriptable version of the searcher module. This allows the entire chatbot model to be run in a scripted mode, which provides faster inference and allows the model to be deployed in production environments.
#
# Overall, these changes enable the chatbot model to be converted into a scriptable format, which can be run on a CPU and deployed in production environments.

# %% [markdown]
# ***Q.3***

# %%
class EncoderRNN(nn.Module):
    def __init__(self, hidden_size, embedding, n_layers=1, dropout=0):
        super(EncoderRNN, self).__init__()
        self.n_layers = n_layers
        self.hidden_size = hidden_size
        self.embedding = embedding

        # Initialize GRU; the input_size and hidden_size params are both set to 'hidden_size'
        #   because our input size is a word embedding with number of features == hidden_size
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers,
                          dropout=(0 if n_layers == 1 else dropout), bidirectional=True)

    def forward(self, input_seq, input_lengths, hidden=None):
        # type: (Tensor, Tensor, Optional[Tensor]) -> Tuple[Tensor, Tensor]
        # Convert word indexes to embeddings
        embedded = self.embedding(input_seq)
        # Pack padded batch of sequences for RNN module
        packed = torch.nn.utils.rnn.pack_padded_sequence(embedded, input_lengths)
        # Forward pass through GRU
        outputs, hidden = self.gru(packed, hidden)
        # Unpack padding
        outputs, _ = torch.nn.utils.rnn.pad_packed_sequence(outputs)
        # Sum bidirectional GRU outputs
        outputs = outputs[:, :, :self.hidden_size] + outputs[:, : ,self.hidden_size:]
        # Return output and final hidden state
        return outputs, hidden

# %%
# Luong attention layer
class Attn(nn.Module):
    def __init__(self, method, hidden_size):
        super(Attn, self).__init__()
        self.method = method
        if self.method not in ['dot', 'general', 'concat']:
            raise ValueError(self.method, "is not an appropriate attention method.")
        self.hidden_size = hidden_size
        if self.method == 'general':
            self.attn = nn.Linear(self.hidden_size, hidden_size)
        elif self.method == 'concat':
            self.attn = nn.Linear(self.hidden_size * 2, hidden_size)
            self.v = nn.Parameter(torch.FloatTensor(hidden_size))

    def dot_score(self, hidden, encoder_output):
        return torch.sum(hidden * encoder_output, dim=2)

    def general_score(self, hidden, encoder_output):
        energy = self.attn(encoder_output)
        return torch.sum(hidden * energy, dim=2)

    def concat_score(self, hidden, encoder_output):
        energy = self.attn(torch.cat((hidden.expand(encoder_output.size(0), -1, -1), encoder_output), 2)).tanh()
        return torch.sum(self.v * energy, dim=2)

    def forward(self, hidden, encoder_outputs):
        # Calculate the attention weights (energies) based on the given method
        if self.method == 'general':
            attn_energies = self.general_score(hidden, encoder_outputs)
        elif self.method == 'concat':
            attn_energies = self.concat_score(hidden, encoder_outputs)
        elif self.method == 'dot':
            attn_energies = self.dot_score(hidden, encoder_outputs)

        # Transpose max_length and batch_size dimensions
        attn_energies = attn_energies.t()

        # Return the softmax normalized probability scores (with added dimension)
        return F.softmax(attn_energies, dim=1).unsqueeze(1)

# %%
# TorchScript Notes:
# ~~~~~~~~~~~~~~~~~~~~~~
#
# Similarly to the ``EncoderRNN``, this module does not contain any
# data-dependent control flow. Therefore, we can once again use
# **tracing** to convert this model to TorchScript after it
# is initialized and its parameters are loaded.
#

class LuongAttnDecoderRNN(nn.Module):
    def __init__(self, attn_model, embedding, hidden_size, output_size, n_layers=1, dropout=0.1):
        super(LuongAttnDecoderRNN, self).__init__()

        # Keep for reference
        self.attn_model = attn_model
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.dropout = dropout

        # Define layers
        self.embedding = embedding
        self.embedding_dropout = nn.Dropout(dropout)
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers, dropout=(0 if n_layers == 1 else dropout))
        self.concat = nn.Linear(hidden_size * 2, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)

        self.attn = Attn(attn_model, hidden_size)

    def forward(self, input_step, last_hidden, encoder_outputs):
        # Note: we run this one step (word) at a time
        # Get embedding of current input word
        embedded = self.embedding(input_step)
        embedded = self.embedding_dropout(embedded)
        # Forward through unidirectional GRU
        rnn_output, hidden = self.gru(embedded, last_hidden)
        # Calculate attention weights from the current GRU output
        attn_weights = self.attn(rnn_output, encoder_outputs)
        # Multiply attention weights to encoder outputs to get new "weighted sum" context vector
        context = attn_weights.bmm(encoder_outputs.transpose(0, 1))
        # Concatenate weighted context vector and GRU output using Luong eq. 5
        rnn_output = rnn_output.squeeze(0)
        context = context.squeeze(1)
        concat_input = torch.cat((rnn_output, context), 1)
        concat_output = torch.tanh(self.concat(concat_input))
        # Predict next word using Luong eq. 6
        output = self.out(concat_output)
        output = F.softmax(output, dim=1)
        # Return output and final hidden state
        return output, hidden

# %%
class GreedySearchDecoder(nn.Module):
    def __init__(self, encoder, decoder, decoder_n_layers):
        super(GreedySearchDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
        self._device = device
        self._SOS_token = SOS_token
        self._decoder_n_layers = decoder_n_layers

    __constants__ = ['_device', '_SOS_token', '_decoder_n_layers']

    def forward(self, input_seq : torch.Tensor, input_length : torch.Tensor, max_length : int):
        # Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        decoder_hidden = encoder_hidden[:self._decoder_n_layers]
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=self._device, dtype=torch.long) * self._SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=self._device, dtype=torch.long)
        all_scores = torch.zeros([0], device=self._device)
        # Iteratively decode one word token at a time
        for _ in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            # Obtain most likely word token and its softmax score
            decoder_scores, decoder_input = torch.max(decoder_output, dim=1)
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores

# %%
def evaluate(searcher, voc, sentence, max_length=MAX_LENGTH):
    ### Format input sentence as a batch
    # words -> indexes
    indexes_batch = [indexesFromSentence(voc, sentence)]
    # Create lengths tensor
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    # Transpose dimensions of batch to match models' expectations
    input_batch = torch.LongTensor(indexes_batch).transpose(0, 1)
    # Use appropriate device
    input_batch = input_batch.to(device)
    lengths = lengths.to(device)
    # Decode sentence with searcher
    tokens, scores = searcher(input_batch, lengths, max_length)
    # indexes -> words
    decoded_words = [voc.index2word[token.item()] for token in tokens]
    return decoded_words


# Evaluate inputs from user input (stdin)
def evaluateInput(searcher, voc):
    input_sentence = ''
    while(1):
        try:
            # Get input sentence
            input_sentence = input('> ')
            # Check if it is quit case
            if input_sentence == 'q' or input_sentence == 'quit': break
            # Normalize sentence
            input_sentence = normalizeString(input_sentence)
            # Evaluate sentence
            output_words = evaluate(searcher, voc, input_sentence)
            # Format and print response sentence
            output_words[:] = [x for x in output_words if not (x == 'EOS' or x == 'PAD')]
            print('Bot:', ' '.join(output_words))

        except KeyError:
            print("Error: Encountered unknown word.")

# Normalize input sentence and call evaluate()
def evaluateExample(sentence, searcher, voc):
    print("> " + sentence)
    # Normalize sentence
    input_sentence = normalizeString(sentence)
    # Evaluate sentence
    output_words = evaluate(searcher, voc, input_sentence)
    output_words[:] = [x for x in output_words if not (x == 'EOS' or x == 'PAD')]
    print('Bot:', ' '.join(output_words))

# %%
# Set checkpoint to load from; set to None if starting from scratch
loadFilename = "/content/drive/MyDrive/data/save/cb_model_BEST_LOSS/movie-corpus/2-2_500/4000_checkpoint.tar"
checkpoint_iter = 4000
#loadFilename = os.path.join(save_dir, model_name, corpus_name,
#                            '{}-{}_{}'.format(encoder_n_layers, decoder_n_layers, hidden_size),
#                            '{}_checkpoint.tar'.format(checkpoint_iter))

model_name = 'cb_model_BEST_LOSS'
attn_model = 'dot'
hidden_size = 500
encoder_n_layers = 2
decoder_n_layers = 2
dropout = 0.1
batch_size = 64
learning_rate = 0.00025

clip =100
teacher_forcing_ratio =0
decoder_learning_ratio =5
n_iteration = 4000
print_every = 500
save_every = 500
# Load model if a loadFilename is provided
if loadFilename:
    # If loading on same machine the model was trained on
    checkpoint = torch.load(loadFilename)
    # If loading a model trained on GPU to CPU
    #checkpoint = torch.load(loadFilename, map_location=torch.device('cpu'))
    encoder_sd = checkpoint['en']
    decoder_sd = checkpoint['de']
    encoder_optimizer_sd = checkpoint['en_opt']
    decoder_optimizer_sd = checkpoint['de_opt']
    embedding_sd = checkpoint['embedding']
    voc.__dict__ = checkpoint['voc_dict']


print('Building encoder and decoder ...')
# Initialize word embeddings
embedding = nn.Embedding(voc.num_words, hidden_size)
if loadFilename:
    embedding.load_state_dict(embedding_sd)
# Initialize encoder & decoder models
encoder = EncoderRNN(hidden_size, embedding, encoder_n_layers, dropout)
decoder = LuongAttnDecoderRNN(attn_model, embedding, hidden_size, voc.num_words, decoder_n_layers, dropout)
if loadFilename:
    encoder.load_state_dict(encoder_sd)
    decoder.load_state_dict(decoder_sd)
# Use appropriate device
encoder = encoder.to(device)
decoder = decoder.to(device)

# Set dropout layers to eval mode
encoder.eval()
decoder.eval()
print('Models built and ready to go!')
# Out:
# Building encoder and decoder ...
# Models built and ready to go!

# %%
### Compile the whole greedy search model to TorchScript model
# Create artificial inputs
test_seq = torch.LongTensor(MAX_LENGTH, 1).random_(0, voc.num_words).to(device)
test_seq_length = torch.LongTensor([test_seq.size()[0]]).to(device)
# Trace the model
traced_encoder = torch.jit.trace(encoder, (test_seq, test_seq_length.to('cpu')))

### Convert decoder model
# Create and generate artificial inputs
test_encoder_outputs, test_encoder_hidden = traced_encoder(test_seq, test_seq_length)
test_decoder_hidden = test_encoder_hidden[:decoder.n_layers]
test_decoder_input = torch.LongTensor(1, 1).random_(0, voc.num_words)
# Trace the model
traced_decoder = torch.jit.trace(decoder, (test_decoder_input.to(device), test_decoder_hidden, test_encoder_outputs.to(device)))

### Initialize searcher module by wrapping ``torch.jit.script`` call
scripted_searcher = torch.jit.script(GreedySearchDecoder(traced_encoder, traced_decoder, decoder.n_layers))

# %% [markdown]
# ***Q.4***

# %%
print('scripted_searcher graph:\n', scripted_searcher.graph)
# Out:
# scripted_searcher graph:
#  graph(%self : __torch__.___torch_mangle_33.GreedySearchDecoder,
#       %input_seq.1 : Tensor,
#       %input_length.1 : Tensor,
#       %max_length.1 : int):
#   %53 : bool = prim::Constant[value=0]()
#   %42 : bool = prim::Constant[value=1]() # <ipython-input-31-7c45bc0b22de>:23:8
#   %18 : int = prim::Constant[value=4]() # <ipython-input-31-7c45bc0b22de>:18:68
#   %17 : Device = prim::Constant[value="cuda"]() # <ipython-input-31-7c45bc0b22de>:18:48
#   %14 : NoneType = prim::Constant()
#   %12 : int = prim::Constant[value=2]() # <ipython-input-31-7c45bc0b22de>:16:41
#   %16 : int = prim::Constant[value=1]() # <ipython-input-31-7c45bc0b22de>:18:35
#   %26 : int = prim::Constant[value=0]() # <ipython-input-31-7c45bc0b22de>:20:34
#   %encoder : __torch__.___torch_mangle_15.EncoderRNN = prim::GetAttr[name="encoder"](%self)
#   %7 : (Tensor, Tensor) = prim::CallMethod[name="forward"](%encoder, %input_seq.1, %input_length.1) # <ipython-input-31-7c45bc0b22de>:14:42
#   %encoder_outputs.1 : Tensor, %encoder_hidden.1 : Tensor = prim::TupleUnpack(%7)
#   %decoder_hidden.1 : Tensor = aten::slice(%encoder_hidden.1, %26, %14, %12, %16) # <ipython-input-31-7c45bc0b22de>:16:25
#   %20 : int[] = prim::ListConstruct(%16, %16)
#   %23 : Tensor = aten::ones(%20, %18, %14, %17, %14) # <ipython-input-31-7c45bc0b22de>:18:24
#   %decoder_input.1 : Tensor = aten::mul(%23, %16) # <ipython-input-31-7c45bc0b22de>:18:24
#   %27 : int[] = prim::ListConstruct(%26)
#   %all_tokens.1 : Tensor = aten::zeros(%27, %18, %14, %17, %14) # <ipython-input-31-7c45bc0b22de>:20:21
#   %33 : int[] = prim::ListConstruct(%26)
#   %all_scores.1 : Tensor = aten::zeros(%33, %14, %14, %17, %14) # <ipython-input-31-7c45bc0b22de>:21:21
#   %all_tokens : Tensor, %all_scores : Tensor, %decoder_hidden : Tensor, %decoder_input : Tensor = prim::Loop(%max_length.1, %42, %all_tokens.1, %all_scores.1, %decoder_hidden.1, %decoder_input.1) # <ipython-input-31-7c45bc0b22de>:23:8
#     block0(%43 : int, %all_tokens.11 : Tensor, %all_scores.11 : Tensor, %decoder_hidden.9 : Tensor, %decoder_input.17 : Tensor):
#       %decoder : __torch__.___torch_mangle_25.LuongAttnDecoderRNN = prim::GetAttr[name="decoder"](%self)
#       %48 : (Tensor, Tensor) = prim::CallMethod[name="forward"](%decoder, %decoder_input.17, %decoder_hidden.9, %encoder_outputs.1) # <ipython-input-31-7c45bc0b22de>:25:45
#       %decoder_output.1 : Tensor, %decoder_hidden.5 : Tensor = prim::TupleUnpack(%48)
#       %decoder_scores.1 : Tensor, %decoder_input.5 : Tensor = aten::max(%decoder_output.1, %16, %53) # <ipython-input-31-7c45bc0b22de>:27:44
#       %61 : Tensor[] = prim::ListConstruct(%all_tokens.11, %decoder_input.5)
#       %all_tokens.5 : Tensor = aten::cat(%61, %26) # <ipython-input-31-7c45bc0b22de>:29:25
#       %67 : Tensor[] = prim::ListConstruct(%all_scores.11, %decoder_scores.1)
#       %all_scores.5 : Tensor = aten::cat(%67, %26) # <ipython-input-31-7c45bc0b22de>:30:25
#       %decoder_input.13 : Tensor = aten::unsqueeze(%decoder_input.5, %26) # <ipython-input-31-7c45bc0b22de>:32:28
#       -> (%42, %all_tokens.5, %all_scores.5, %decoder_hidden.5, %decoder_input.13)
#   %75 : (Tensor, Tensor) = prim::TupleConstruct(%all_tokens, %all_scores)
#   return (%75)

# %% [markdown]
# ***Q.5***

# %%
# Use appropriate device
scripted_searcher.to(device)
# Set dropout layers to eval mode
scripted_searcher.eval()

# Evaluate examples
sentences = ["hello", "what's up?", "who are you?", "where am I?", "where are you from?"]
for s in sentences:
    evaluateExample(s, scripted_searcher, voc)

# Evaluate your input
#evaluateInput(traced_encoder, traced_decoder, scripted_searcher, voc)
# Out:
# > hello
# Bot: hello . .
# > what's up?
# Bot: shhhh shark shark the tank shark shark tank .
# > who are you?
# Bot: i parole the . . .
# > where am I?
# Bot: in . . .
# > where are you from?
# Bot: san .

# %% [markdown]
# ***Q.6***

# %%
with profile(activities=[
        ProfilerActivity.CPU, ProfilerActivity.CUDA], profile_memory=True, record_shapes=True) as prof:
    with record_function("model_inference"):

      # Use appropriate device
      scripted_searcher.to(device)
      # Set dropout layers to eval mode
      scripted_searcher.eval()
      # Evaluate examples
      sentences = ["hello", "what's up?", "who are you?", "where am I?", "where are you from?"]
      for s in sentences:
          evaluateExample(s, scripted_searcher, voc)
# Out:
# > hello
# Bot: hello . .
# > what's up?
# Bot: shhhh shark shark the tank shark shark tank .
# > who are you?
# Bot: i parole the . . .
# > where am I?
# Bot: in . . .
# > where are you from?
# Bot: san .

# %%
#Time Consumption
print(prof.key_averages().table(sort_by="cuda_time_total", row_limit=10))
# Out:
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg       CPU Mem  Self CPU Mem      CUDA Mem  Self CUDA Mem    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                         model_inference        11.88%      10.578ms        99.95%      89.031ms      89.031ms       0.000us         0.00%      21.397ms      21.397ms           0 b        -320 b           0 b      -4.09 Mb             1
#                                                 forward         9.80%       8.731ms        80.82%      71.990ms      14.398ms       0.000us         0.00%      21.337ms       4.267ms         184 b         -48 b       4.09 Mb    -175.50 Kb             5
#                                               aten::gru         4.28%       3.809ms        28.13%      25.057ms     455.582us       0.000us         0.00%      11.311ms     205.655us           0 b           0 b     431.50 Kb           0 b            55
#                                        aten::_cudnn_rnn        13.61%      12.119ms        22.61%      20.139ms     366.164us      11.311ms        51.58%      11.311ms     205.655us           0 b           0 b     431.50 Kb      -1.64 Gb            55
# void gemv2T_kernel_val<int, int, float, float, float...         0.00%       0.000us         0.00%       0.000us       0.000us       8.427ms        38.43%       8.427ms      28.860us           0 b           0 b           0 b           0 b           292
#                                            aten::linear         0.61%     545.000us         9.46%       8.424ms      84.240us       0.000us         0.00%       5.431ms      54.310us           0 b           0 b       1.61 Mb           0 b           100
#                                             aten::addmm         4.21%       3.751ms         7.89%       7.030ms      70.300us       5.431ms        24.77%       5.431ms      54.310us           0 b           0 b       1.61 Mb     -98.39 Mb           100
# void gemv2T_kernel_val<int, int, float, float, float...         0.00%       0.000us         0.00%       0.000us       0.000us       4.351ms        19.84%       4.351ms      87.020us           0 b           0 b           0 b           0 b            50
# void elemWiseRNNcell<float, float, float, (cudnnRNNM...         0.00%       0.000us         0.00%       0.000us       0.000us       1.355ms         6.18%       1.355ms       7.057us           0 b           0 b           0 b           0 b           192
# void gemmSN_TN_kernel<float, 128, 16, 2, 4, 6, 7, fa...         0.00%       0.000us         0.00%       0.000us       0.000us       1.112ms         5.07%       1.112ms      79.429us           0 b           0 b           0 b           0 b            14
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 89.077ms
# Self CUDA time total: 21.927ms

# %% [markdown]
# ***Q.7***

# %%
scripted_searcher.save("scripted_chatbot.pth")
